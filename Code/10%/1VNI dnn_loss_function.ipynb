# %%
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
from tqdm.notebook import tqdm
from datetime import timedelta
import matplotlib.pyplot as plt
from IPython.display import Image
import plotly.graph_objects as go
from keras.utils import plot_model
from keras.models import Sequential
from IPython.display import Image, display
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from tensorflow.keras.layers import Embedding, SpatialDropout1D, Bidirectional, LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/1VNIndex.xlsx' # Đường dẫn đã được cập nhật
df = pd.read_excel(file_path)
# Out:
# Mounted at /content/drive

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#              Price
# Date
# 2000-07-31  101.55
# 2000-08-02  103.38
# 2000-08-04  105.20
# 2000-08-07  106.92
# 2000-08-09  108.64

# %%
return_series=np.log(df['Price']/df['Price'].shift(1))

# %%
return_series = return_series.dropna()

# %%
return_series
# Out:
# Date
# 2000-08-02    0.017860
# 2000-08-04    0.017452
# 2000-08-07    0.016218
# 2000-08-09    0.015959
# 2000-08-11    0.015708
#                 ...
# 2024-12-10   -0.001390
# 2024-12-11   -0.002527
# 2024-12-12   -0.001191
# 2024-12-13   -0.003779
# 2024-12-16    0.000966
# Name: Price, Length: 5931, dtype: float64

# %%
r_t=return_series.values.reshape(5931,1)

# %%
# prompt: đưa ra bảng mô tả thống kê, kurtosis, jacque cho r_t

import pandas as pd
import numpy as np

# Assuming 'return_series' and 'r_t' are defined as in the previous code
# ... (your existing code) ...

# Calculate descriptive statistics
r_t_series = pd.Series(r_t.flatten()) # Convert r_t to a pandas Series for easier calculations
description = r_t_series.describe()

# Calculate kurtosis and skewness (Fisher's definition)
kurtosis = r_t_series.kurtosis()
skewness = r_t_series.skew()


# Print the results
print("Descriptive Statistics:")
print(description)
print("\nKurtosis:", kurtosis)
print("\nSkewness (Fisher):", skewness)

# Create a summary table
summary_table = pd.DataFrame({
    'Statistic': ['Count', 'Mean', 'Standard Deviation', 'Min', '25%', '50%', '75%', 'Max', 'Kurtosis', 'Skewness'],
    'Value': [description['count'], description['mean'], description['std'], description['min'], description['25%'],
              description['50%'], description['75%'], description['max'], kurtosis, skewness]
})

print("\nSummary Table:")
summary_table
# Out:
# Descriptive Statistics:
# count    5931.000000
# mean        0.000425
# std         0.014439
# min        -0.076557
# 25%        -0.005534
# 50%         0.000607
# 75%         0.007378
# max         0.066561
# dtype: float64
#
# Kurtosis: 3.4097427278606807
#
# Skewness (Fisher): -0.3953987594767815
#
# Summary Table:
#             Statistic        Value
# 0               Count  5931.000000
# 1                Mean     0.000425
# 2  Standard Deviation     0.014439
# 3                 Min    -0.076557
# 4                 25%    -0.005534
# 5                 50%     0.000607
# 6                 75%     0.007378
# 7                 Max     0.066561
# 8            Kurtosis     3.409743
# 9            Skewness    -0.395399

# %%
# prompt: đưa ra kết quả jacque bera test cho r_t

import numpy as np
import pandas as pd
from scipy.stats import jarque_bera

# Assuming 'r_t' is defined as in the previous code
# ... (your existing code) ...

# Perform Jarque-Bera test
jb_statistic, p_value = jarque_bera(r_t.flatten())

print("\nJarque-Bera Test:")
print("Statistic:", jb_statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The data does not follow a normal distribution.")
else:
    print("Fail to reject the null hypothesis: The data may follow a normal distribution.")
# Out:
# Jarque-Bera Test:
# Statistic: 3021.0807048199413
# p-value: 0.0
# Reject the null hypothesis: The data does not follow a normal distribution.

# %%
from matplotlib import pyplot as plt
plt.plot(r_t)
plt.show()

# %%
plt.plot(r_t[:42])
plt.xticks(rotation=45)
plt.show()

# %%
seq_len = 11
sequence = []
for index in range(len(r_t) - seq_len + 1):
    sequence.append(r_t[index: index + seq_len])
sequence = np.array(sequence)
print(sequence.shape)
# Out:
# (5921, 11, 1)

# %%
def split_data(sequence):
    train_data, test_data = train_test_split(sequence, test_size=0.2, shuffle=False,random_state=42)
    val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=False,random_state=42)
    return train_data, val_data, test_data

# %%
train_data, val_data, test_data = split_data(sequence)
print("Train:", train_data.shape, "Validation:", val_data.shape, "Test:", test_data.shape)
# Out:
# Train: (4736, 11, 1) Validation: (592, 11, 1) Test: (593, 11, 1)

# %%
# Rải phẳng dữ liệu cho mô hình DNN
x_train = train_data[:, :-1, :].reshape(train_data.shape[0], -1)  # Flatten (samples, timesteps * features)
y_train = train_data[:, -1, -1]  # Target (samples,)

x_valid = val_data[:, :-1, :].reshape(val_data.shape[0], -1)  # Flatten validation set
y_valid = val_data[:, -1, -1]

x_test = test_data[:, :-1, :].reshape(test_data.shape[0], -1)  # Flatten test set
y_test = test_data[:, -1, -1]

# Kiểm tra kích thước của các tập dữ liệu
print(f"x_train shape: {x_train.shape}")  # (samples, timesteps * features)
print(f"y_train shape: {y_train.shape}")  # (samples,)
print(f"x_valid shape: {x_valid.shape}")
print(f"y_valid shape: {y_valid.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4736, 10)
# y_train shape: (4736,)
# x_valid shape: (592, 10)
# y_valid shape: (592,)
# x_test shape: (593, 10)
# y_test shape: (593,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K

# %%
import math
pi=math.pi
pi
# Out:
# 3.141592653589793

# %%
def log_likelihood_loss(y_true, y_pred):
    # Giả sử y_pred chứa cả giá trị dự đoán (r_t) và độ biến động (sigma_t)
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = y_pred  # Độ biến động dự đoán (sigma_t)

    # Tính log-likelihood loss
    loss = K.sum(2 * K.log(sigma_t) + K.square(r_t) / K.square(sigma_t), axis=-1)
    return loss
def log_likelihood_function(y_true, y_pred):
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = tf.cast(y_pred, dtype=tf.float32) # Cast y_pred to tf.float32 as well
    # Constants
    import math
    pi=math.pi

    # Calculate log-likelihood using TensorFlow operations
    log_likelihood = K.sum(-0.5*K.log(2*pi) - 2 * K.log(sigma_t) - K.square(r_t) / K.square(sigma_t))

    return log_likelihood

def build_dnn_model(input_length, dnn_units, fc_units, dropout_rate, optimizer):
    model = Sequential()

    # Dense layer (instead of LSTM) - Changed input_shape to a tuple
    model.add(Dense(units=dnn_units))

    # Fully connected layer (Dense)
    model.add(Dense(fc_units, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Output layer - output sigma_t (độ biến động dự đoán)
    model.add(Dense(1, activation='sigmoid'))

    # Biên dịch mô hình với hàm mất mát log-likelihood
    model.compile(optimizer=optimizer, loss=log_likelihood_loss, metrics=[log_likelihood_function])

    return model

# %%
import tensorflow as tf
input_length = 10  # Độ dài chuỗi đầu vào
dnn_units = 20    # Số lượng units trong lớp LSTM
fc_units = 40      # Số lượng units trong lớp fully connected
dropout_rate = 0.3 # Tỷ lệ dropout
batch_size = 32  # Kích thước batch
epochs = 500        # Số epoch cho quá trình huấn luyện
optimizer = RMSprop()
# Xây dựng mô hình
model = build_dnn_model(input_length, dnn_units, fc_units, dropout_rate,optimizer)

# Huấn luyện mô hình với dữ liệu generator
history = model.fit(
    x_train,
    y_train,                    # Dữ liệu huấn luyện
    steps_per_epoch=100, # Số bước mỗi epoch
    epochs=epochs,                # Số epoch
    validation_data=(x_valid,y_valid),      # Dữ liệu xác thực
    batch_size=batch_size,
    shuffle= False  # Kích thước batch
    )

# Đánh giá mô hình trên tập kiểm tra (test)
test_loss, test_log_likelihood = model.evaluate(x_test, y_test)
print(f"Test loss (Log-Likelihood): {test_loss}")
print(f"Test log-likelihood: {test_log_likelihood}")
# Out:
# Epoch 1/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - log_likelihood_function: 991.4562 - loss: -1.8871 - val_log_likelihood_function: 4290.6826 - val_loss: -5.2816
# Epoch 2/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5577.4160 - loss: -6.3862 - val_log_likelihood_function: 6443.8584 - val_loss: -7.4864
# Epoch 3/500
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5339.0869 - loss: -6.2127 - val_log_likelihood_function: 6488.4189 - val_loss: -7.5316
# Epoch 4/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6398.4160 - loss: -7.1070 - val_log_likelihood_function: 6435.4517 - val_loss: -7.4810
# Epoch 5/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5346.6992 - loss: -6.0512 - val_log_likelihood_function: 6546.3218 - val_loss: -7.6001
# Epoch 6/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6458.2363 - loss: -7.2094 - val_log_likelihood_function: 6549.0532 - val_loss: -7.6041
# Epoch 7/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 4936.6313 - loss: -5.7677 - val_log_likelihood_function: 6549.7998 - val_loss: -7.6005
# Epoch 8/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6484.9688 - loss: -7.2815 - val_log_likelihood_function: 6538.7012 - val_loss: -7.5948
# Epoch 9/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5263.8813 - loss: -6.1347 - val_log_likelihood_function: 6522.8008 - val_loss: -7.5724
# Epoch 10/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6538.5234 - loss: -7.3663 - val_log_likelihood_function: 6498.0869 - val_loss: -7.5511
# Epoch 11/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5474.7954 - loss: -6.2989 - val_log_likelihood_function: 6521.3462 - val_loss: -7.5728
# Epoch 12/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6477.8833 - loss: -7.1257 - val_log_likelihood_function: 6500.1133 - val_loss: -7.5520
# Epoch 13/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5485.8340 - loss: -6.2676 - val_log_likelihood_function: 6554.6289 - val_loss: -7.6073
# Epoch 14/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6429.0952 - loss: -7.2976 - val_log_likelihood_function: 6529.4307 - val_loss: -7.5853
# Epoch 15/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5188.2266 - loss: -5.7424 - val_log_likelihood_function: 6539.2202 - val_loss: -7.5899
# Epoch 16/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6452.5708 - loss: -7.2263 - val_log_likelihood_function: 6494.5703 - val_loss: -7.5478
# Epoch 17/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5418.5352 - loss: -6.2424 - val_log_likelihood_function: 6534.9956 - val_loss: -7.5895
# Epoch 18/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6618.9585 - loss: -7.4303 - val_log_likelihood_function: 6543.7607 - val_loss: -7.6058
# Epoch 19/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5354.3384 - loss: -5.7763 - val_log_likelihood_function: 6478.0938 - val_loss: -7.5257
# Epoch 20/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - log_likelihood_function: 6547.6709 - loss: -7.4575 - val_log_likelihood_function: 6528.1089 - val_loss: -7.5874
# Epoch 21/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - log_likelihood_function: 5315.6460 - loss: -6.1110 - val_log_likelihood_function: 6554.6807 - val_loss: -7.6157
# Epoch 22/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6527.2407 - loss: -7.3755 - val_log_likelihood_function: 6510.7070 - val_loss: -7.5702
# Epoch 23/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - log_likelihood_function: 5619.9814 - loss: -6.3890 - val_log_likelihood_function: 6555.4780 - val_loss: -7.6189
# Epoch 24/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6587.6997 - loss: -7.1671 - val_log_likelihood_function: 6503.8301 - val_loss: -7.5613
# Epoch 25/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - log_likelihood_function: 5573.6943 - loss: -6.4349 - val_log_likelihood_function: 6555.3232 - val_loss: -7.6231
# Epoch 26/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - log_likelihood_function: 6596.9282 - loss: -7.4417 - val_log_likelihood_function: 6554.9878 - val_loss: -7.6272
# Epoch 27/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - log_likelihood_function: 5501.0444 - loss: -6.4770 - val_log_likelihood_function: 6551.4263 - val_loss: -7.6151
# Epoch 28/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6438.9824 - loss: -7.3264 - val_log_likelihood_function: 6521.9355 - val_loss: -7.5888
# Epoch 29/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - log_likelihood_function: 5597.0806 - loss: -6.4973 - val_log_likelihood_function: 6493.7378 - val_loss: -7.5494
# Epoch 30/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6533.3989 - loss: -7.3246 - val_log_likelihood_function: 6558.0947 - val_loss: -7.6355
# Epoch 31/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5280.1787 - loss: -6.4694 - val_log_likelihood_function: 6543.3789 - val_loss: -7.6057
# Epoch 32/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6628.5112 - loss: -7.2927 - val_log_likelihood_function: 6555.8789 - val_loss: -7.6301
# Epoch 33/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5271.0073 - loss: -6.1300 - val_log_likelihood_function: 6508.3374 - val_loss: -7.5644
# Epoch 34/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6586.6694 - loss: -7.4328 - val_log_likelihood_function: 6550.6924 - val_loss: -7.6209
# Epoch 35/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5492.5630 - loss: -6.3558 - val_log_likelihood_function: 6541.5903 - val_loss: -7.5959
# Epoch 36/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6593.5928 - loss: -7.3674 - val_log_likelihood_function: 6471.9570 - val_loss: -7.5254
# Epoch 37/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5600.2446 - loss: -6.2792 - val_log_likelihood_function: 6548.3442 - val_loss: -7.6138
# Epoch 38/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6549.7104 - loss: -7.4867 - val_log_likelihood_function: 6535.5430 - val_loss: -7.5973
# Epoch 39/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5525.9766 - loss: -6.1281 - val_log_likelihood_function: 6540.1968 - val_loss: -7.5934
# Epoch 40/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6616.9194 - loss: -7.2754 - val_log_likelihood_function: 6511.1362 - val_loss: -7.5666
# Epoch 41/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5524.4756 - loss: -6.3662 - val_log_likelihood_function: 6552.2480 - val_loss: -7.6102
# Epoch 42/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6591.6094 - loss: -7.4102 - val_log_likelihood_function: 6524.4326 - val_loss: -7.5873
# Epoch 43/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5426.4688 - loss: -6.2650 - val_log_likelihood_function: 6518.2119 - val_loss: -7.5664
# Epoch 44/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6630.5518 - loss: -7.3638 - val_log_likelihood_function: 6535.0854 - val_loss: -7.5934
# Epoch 45/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5567.0703 - loss: -6.4178 - val_log_likelihood_function: 6551.5000 - val_loss: -7.6069
# Epoch 46/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6537.7163 - loss: -7.3679 - val_log_likelihood_function: 6537.6460 - val_loss: -7.5966
# Epoch 47/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5601.0234 - loss: -6.3262 - val_log_likelihood_function: 6550.9028 - val_loss: -7.6043
# Epoch 48/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6589.6255 - loss: -7.4019 - val_log_likelihood_function: 6547.0269 - val_loss: -7.6076
# Epoch 49/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5350.5742 - loss: -6.1445 - val_log_likelihood_function: 6550.2339 - val_loss: -7.6057
# Epoch 50/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6666.4355 - loss: -7.5399 - val_log_likelihood_function: 6560.8193 - val_loss: -7.6381
# Epoch 51/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5355.3545 - loss: -6.3378 - val_log_likelihood_function: 6550.3159 - val_loss: -7.6062
# Epoch 52/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6654.4966 - loss: -7.4545 - val_log_likelihood_function: 6540.3706 - val_loss: -7.6052
# Epoch 53/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5747.8335 - loss: -6.6704 - val_log_likelihood_function: 6521.2954 - val_loss: -7.5680
# Epoch 54/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6693.3149 - loss: -7.6214 - val_log_likelihood_function: 6562.1094 - val_loss: -7.6374
# Epoch 55/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5436.6367 - loss: -6.2201 - val_log_likelihood_function: 6542.1187 - val_loss: -7.6070
# Epoch 56/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6698.2432 - loss: -7.5493 - val_log_likelihood_function: 6561.6313 - val_loss: -7.6477
# Epoch 57/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5582.8477 - loss: -6.4932 - val_log_likelihood_function: 6522.6187 - val_loss: -7.5746
# Epoch 58/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6658.6514 - loss: -7.5251 - val_log_likelihood_function: 6548.8813 - val_loss: -7.6252
# Epoch 59/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5667.4346 - loss: -6.5828 - val_log_likelihood_function: 6519.6299 - val_loss: -7.5673
# Epoch 60/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6638.0063 - loss: -7.4146 - val_log_likelihood_function: 6550.1831 - val_loss: -7.6255
# Epoch 61/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5569.3765 - loss: -6.3941 - val_log_likelihood_function: 6556.5459 - val_loss: -7.6183
# Epoch 62/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6607.5220 - loss: -7.4844 - val_log_likelihood_function: 6568.4263 - val_loss: -7.6693
# Epoch 63/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5534.3604 - loss: -6.3830 - val_log_likelihood_function: 6551.5796 - val_loss: -7.6115
# Epoch 64/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6654.4165 - loss: -7.3744 - val_log_likelihood_function: 6536.8062 - val_loss: -7.6173
# Epoch 65/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5684.6851 - loss: -6.5376 - val_log_likelihood_function: 6503.0586 - val_loss: -7.5539
# Epoch 66/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6739.6802 - loss: -7.4607 - val_log_likelihood_function: 6565.4814 - val_loss: -7.6549
# Epoch 67/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5762.0469 - loss: -6.6083 - val_log_likelihood_function: 6548.1860 - val_loss: -7.6122
# Epoch 68/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6689.4653 - loss: -7.4175 - val_log_likelihood_function: 6561.2168 - val_loss: -7.6623
# Epoch 69/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5553.8892 - loss: -6.0785 - val_log_likelihood_function: 6549.9028 - val_loss: -7.6069
# Epoch 70/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6730.1855 - loss: -7.4185 - val_log_likelihood_function: 6571.3545 - val_loss: -7.6728
# Epoch 71/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5551.7231 - loss: -6.2970 - val_log_likelihood_function: 6548.1714 - val_loss: -7.6024
# Epoch 72/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6615.7744 - loss: -7.4034 - val_log_likelihood_function: 6567.9775 - val_loss: -7.6566
# Epoch 73/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5548.8838 - loss: -6.3927 - val_log_likelihood_function: 6537.7056 - val_loss: -7.5917
# Epoch 74/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6759.9922 - loss: -7.4742 - val_log_likelihood_function: 6565.6475 - val_loss: -7.6655
# Epoch 75/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5728.8638 - loss: -6.6134 - val_log_likelihood_function: 6553.5293 - val_loss: -7.6120
# Epoch 76/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6738.4668 - loss: -7.5838 - val_log_likelihood_function: 6575.0205 - val_loss: -7.6803
# Epoch 77/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5587.3262 - loss: -6.3430 - val_log_likelihood_function: 6553.8413 - val_loss: -7.6185
# Epoch 78/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6730.1460 - loss: -7.4033 - val_log_likelihood_function: 6570.2012 - val_loss: -7.6675
# Epoch 79/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5764.7041 - loss: -6.4824 - val_log_likelihood_function: 6544.3052 - val_loss: -7.6030
# Epoch 80/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6716.9917 - loss: -7.4909 - val_log_likelihood_function: 6577.2368 - val_loss: -7.6879
# Epoch 81/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5608.5386 - loss: -6.4296 - val_log_likelihood_function: 6555.8027 - val_loss: -7.6230
# Epoch 82/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6751.3066 - loss: -7.4611 - val_log_likelihood_function: 6567.2251 - val_loss: -7.6715
# Epoch 83/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5754.0088 - loss: -6.5773 - val_log_likelihood_function: 6553.6265 - val_loss: -7.6085
# Epoch 84/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6740.4517 - loss: -7.5437 - val_log_likelihood_function: 6548.7651 - val_loss: -7.6556
# Epoch 85/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5914.4790 - loss: -6.6325 - val_log_likelihood_function: 6566.7861 - val_loss: -7.6464
# Epoch 86/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6706.3882 - loss: -7.4705 - val_log_likelihood_function: 6576.9067 - val_loss: -7.6915
# Epoch 87/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5802.6665 - loss: -6.6903 - val_log_likelihood_function: 6542.7827 - val_loss: -7.6032
# Epoch 88/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6707.0596 - loss: -7.5749 - val_log_likelihood_function: 6583.4258 - val_loss: -7.7274
# Epoch 89/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5752.1597 - loss: -6.6631 - val_log_likelihood_function: 6543.4419 - val_loss: -7.5939
# Epoch 90/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6756.1860 - loss: -7.5451 - val_log_likelihood_function: 6580.7539 - val_loss: -7.6921
# Epoch 91/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5752.0146 - loss: -6.7038 - val_log_likelihood_function: 6526.3359 - val_loss: -7.6091
# Epoch 92/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6680.8198 - loss: -7.4882 - val_log_likelihood_function: 6581.3252 - val_loss: -7.7012
# Epoch 93/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5854.7021 - loss: -6.6630 - val_log_likelihood_function: 6565.8843 - val_loss: -7.6428
# Epoch 94/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6712.0112 - loss: -7.5489 - val_log_likelihood_function: 6579.6846 - val_loss: -7.6955
# Epoch 95/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5957.2549 - loss: -6.8707 - val_log_likelihood_function: 6555.5889 - val_loss: -7.6048
# Epoch 96/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6745.4868 - loss: -7.5803 - val_log_likelihood_function: 6583.8521 - val_loss: -7.7031
# Epoch 97/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5910.7285 - loss: -6.7194 - val_log_likelihood_function: 6564.3135 - val_loss: -7.6279
# Epoch 98/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6705.7188 - loss: -7.5992 - val_log_likelihood_function: 6588.5522 - val_loss: -7.7348
# Epoch 99/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5762.3164 - loss: -6.7029 - val_log_likelihood_function: 6558.6147 - val_loss: -7.6237
# Epoch 100/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6756.9351 - loss: -7.6147 - val_log_likelihood_function: 6585.5376 - val_loss: -7.7014
# Epoch 101/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5764.6201 - loss: -6.7213 - val_log_likelihood_function: 6553.8716 - val_loss: -7.6008
# Epoch 102/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6792.0322 - loss: -7.6070 - val_log_likelihood_function: 6588.3096 - val_loss: -7.7147
# Epoch 103/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5916.6553 - loss: -6.8501 - val_log_likelihood_function: 6548.4087 - val_loss: -7.5925
# Epoch 104/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6815.5605 - loss: -7.6341 - val_log_likelihood_function: 6582.3330 - val_loss: -7.6926
# Epoch 105/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5944.4600 - loss: -6.8308 - val_log_likelihood_function: 6534.0410 - val_loss: -7.5675
# Epoch 106/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6808.2002 - loss: -7.6038 - val_log_likelihood_function: 6578.2798 - val_loss: -7.6983
# Epoch 107/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6049.0957 - loss: -6.8771 - val_log_likelihood_function: 6508.3979 - val_loss: -7.5856
# Epoch 108/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6818.4087 - loss: -7.5641 - val_log_likelihood_function: 6586.5322 - val_loss: -7.7139
# Epoch 109/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5761.7280 - loss: -6.7635 - val_log_likelihood_function: 6572.2402 - val_loss: -7.6491
# Epoch 110/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6754.5752 - loss: -7.7489 - val_log_likelihood_function: 6590.3901 - val_loss: -7.7352
# Epoch 111/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5944.7480 - loss: -6.9358 - val_log_likelihood_function: 6553.6104 - val_loss: -7.5965
# Epoch 112/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6831.9385 - loss: -7.5437 - val_log_likelihood_function: 6594.4604 - val_loss: -7.7253
# Epoch 113/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5846.8062 - loss: -6.8820 - val_log_likelihood_function: 6572.9961 - val_loss: -7.6564
# Epoch 114/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6790.0659 - loss: -7.5548 - val_log_likelihood_function: 6594.6675 - val_loss: -7.7252
# Epoch 115/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5920.0630 - loss: -6.8069 - val_log_likelihood_function: 6575.8477 - val_loss: -7.6401
# Epoch 116/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6826.7153 - loss: -7.6909 - val_log_likelihood_function: 6542.7812 - val_loss: -7.6918
# Epoch 117/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5787.8398 - loss: -6.8138 - val_log_likelihood_function: 6572.3496 - val_loss: -7.6496
# Epoch 118/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6803.7568 - loss: -7.5709 - val_log_likelihood_function: 6594.0781 - val_loss: -7.7140
# Epoch 119/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6029.0269 - loss: -7.0615 - val_log_likelihood_function: 6555.2549 - val_loss: -7.6143
# Epoch 120/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6719.4707 - loss: -7.7415 - val_log_likelihood_function: 6598.3657 - val_loss: -7.7325
# Epoch 121/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5974.4478 - loss: -6.9286 - val_log_likelihood_function: 6572.3262 - val_loss: -7.6427
# Epoch 122/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6822.1006 - loss: -7.6587 - val_log_likelihood_function: 6576.8481 - val_loss: -7.7068
# Epoch 123/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5955.9922 - loss: -6.9631 - val_log_likelihood_function: 6540.7900 - val_loss: -7.5850
# Epoch 124/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6858.4014 - loss: -7.7239 - val_log_likelihood_function: 6595.5947 - val_loss: -7.7254
# Epoch 125/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6010.6333 - loss: -6.8773 - val_log_likelihood_function: 6559.8145 - val_loss: -7.6242
# Epoch 126/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6850.1270 - loss: -7.6058 - val_log_likelihood_function: 6593.3906 - val_loss: -7.7183
# Epoch 127/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6155.7905 - loss: -7.0312 - val_log_likelihood_function: 6563.9619 - val_loss: -7.6248
# Epoch 128/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6834.5508 - loss: -7.6003 - val_log_likelihood_function: 6566.4048 - val_loss: -7.7172
# Epoch 129/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6019.8877 - loss: -7.0811 - val_log_likelihood_function: 6564.8940 - val_loss: -7.6157
# Epoch 130/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6859.2144 - loss: -7.7471 - val_log_likelihood_function: 6602.2021 - val_loss: -7.7486
# Epoch 131/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5990.7534 - loss: -6.9309 - val_log_likelihood_function: 6584.8428 - val_loss: -7.6719
# Epoch 132/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6827.4160 - loss: -7.6596 - val_log_likelihood_function: 6588.1660 - val_loss: -7.7212
# Epoch 133/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6040.9526 - loss: -7.0266 - val_log_likelihood_function: 6579.4585 - val_loss: -7.6472
# Epoch 134/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6843.4062 - loss: -7.6044 - val_log_likelihood_function: 6599.7378 - val_loss: -7.7358
# Epoch 135/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5934.7646 - loss: -6.9661 - val_log_likelihood_function: 6579.1157 - val_loss: -7.6422
# Epoch 136/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6891.3789 - loss: -7.6750 - val_log_likelihood_function: 6595.9170 - val_loss: -7.7309
# Epoch 137/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6180.9966 - loss: -7.1271 - val_log_likelihood_function: 6585.2876 - val_loss: -7.6689
# Epoch 138/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6892.1694 - loss: -7.6534 - val_log_likelihood_function: 6597.8477 - val_loss: -7.7426
# Epoch 139/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6108.2578 - loss: -7.0432 - val_log_likelihood_function: 6574.7437 - val_loss: -7.6396
# Epoch 140/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6853.2202 - loss: -7.6864 - val_log_likelihood_function: 6543.9043 - val_loss: -7.6886
# Epoch 141/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5849.6460 - loss: -6.7981 - val_log_likelihood_function: 6580.0869 - val_loss: -7.6443
# Epoch 142/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6873.5762 - loss: -7.6215 - val_log_likelihood_function: 6595.8574 - val_loss: -7.7137
# Epoch 143/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6212.3477 - loss: -7.1614 - val_log_likelihood_function: 6588.1313 - val_loss: -7.6724
# Epoch 144/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6894.5640 - loss: -7.6850 - val_log_likelihood_function: 6577.9009 - val_loss: -7.7160
# Epoch 145/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6104.2832 - loss: -7.0748 - val_log_likelihood_function: 6564.2227 - val_loss: -7.6350
# Epoch 146/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6920.8389 - loss: -7.7782 - val_log_likelihood_function: 6598.8906 - val_loss: -7.7311
# Epoch 147/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6076.3188 - loss: -7.1563 - val_log_likelihood_function: 6586.3252 - val_loss: -7.6671
# Epoch 148/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6880.3311 - loss: -7.7618 - val_log_likelihood_function: 6586.8218 - val_loss: -7.7432
# Epoch 149/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5943.3364 - loss: -6.9408 - val_log_likelihood_function: 6514.4829 - val_loss: -7.5724
# Epoch 150/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6947.2944 - loss: -7.6959 - val_log_likelihood_function: 6593.5698 - val_loss: -7.7497
# Epoch 151/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6038.4912 - loss: -7.1152 - val_log_likelihood_function: 6584.4106 - val_loss: -7.6555
# Epoch 152/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6911.5938 - loss: -7.6864 - val_log_likelihood_function: 6589.9829 - val_loss: -7.7407
# Epoch 153/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6150.4551 - loss: -7.1350 - val_log_likelihood_function: 6586.4614 - val_loss: -7.6699
# Epoch 154/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6961.9268 - loss: -7.7142 - val_log_likelihood_function: 6591.4531 - val_loss: -7.7521
# Epoch 155/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6119.2427 - loss: -7.1176 - val_log_likelihood_function: 6571.3599 - val_loss: -7.6586
# Epoch 156/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6921.6221 - loss: -7.7931 - val_log_likelihood_function: 6545.8608 - val_loss: -7.7387
# Epoch 157/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5992.7495 - loss: -7.0538 - val_log_likelihood_function: 6507.7617 - val_loss: -7.5962
# Epoch 158/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6888.8579 - loss: -7.7975 - val_log_likelihood_function: 6590.0117 - val_loss: -7.7427
# Epoch 159/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6198.7100 - loss: -7.1188 - val_log_likelihood_function: 6575.0195 - val_loss: -7.6555
# Epoch 160/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6933.2686 - loss: -7.7673 - val_log_likelihood_function: 6595.6523 - val_loss: -7.7524
# Epoch 161/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6197.3960 - loss: -7.1786 - val_log_likelihood_function: 6581.4473 - val_loss: -7.6811
# Epoch 162/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6876.4062 - loss: -7.7228 - val_log_likelihood_function: 6555.8848 - val_loss: -7.7361
# Epoch 163/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6040.6348 - loss: -6.9976 - val_log_likelihood_function: 6589.5479 - val_loss: -7.6795
# Epoch 164/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6969.2681 - loss: -7.8709 - val_log_likelihood_function: 6582.8247 - val_loss: -7.7687
# Epoch 165/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6169.4580 - loss: -7.1586 - val_log_likelihood_function: 6591.2388 - val_loss: -7.6855
# Epoch 166/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6964.1152 - loss: -7.8425 - val_log_likelihood_function: 6598.9829 - val_loss: -7.7645
# Epoch 167/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6194.2173 - loss: -7.1222 - val_log_likelihood_function: 6546.0112 - val_loss: -7.6199
# Epoch 168/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6948.4941 - loss: -7.7987 - val_log_likelihood_function: 6597.2012 - val_loss: -7.7447
# Epoch 169/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6057.8931 - loss: -7.0680 - val_log_likelihood_function: 6582.3892 - val_loss: -7.6714
# Epoch 170/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6947.6094 - loss: -7.9134 - val_log_likelihood_function: 6595.2437 - val_loss: -7.7658
# Epoch 171/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6200.2559 - loss: -7.2341 - val_log_likelihood_function: 6592.1113 - val_loss: -7.6808
# Epoch 172/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6988.3657 - loss: -7.7711 - val_log_likelihood_function: 6600.6694 - val_loss: -7.7442
# Epoch 173/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6246.9209 - loss: -7.2443 - val_log_likelihood_function: 6589.7949 - val_loss: -7.6816
# Epoch 174/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6943.0107 - loss: -7.7524 - val_log_likelihood_function: 6577.3081 - val_loss: -7.7407
# Epoch 175/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6091.9927 - loss: -7.1990 - val_log_likelihood_function: 6528.8047 - val_loss: -7.6309
# Epoch 176/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6937.3057 - loss: -7.8858 - val_log_likelihood_function: 6594.4775 - val_loss: -7.7641
# Epoch 177/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6140.7559 - loss: -7.2803 - val_log_likelihood_function: 6556.5898 - val_loss: -7.6473
# Epoch 178/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6978.3208 - loss: -7.7160 - val_log_likelihood_function: 6580.7168 - val_loss: -7.7407
# Epoch 179/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6193.5278 - loss: -7.1363 - val_log_likelihood_function: 6571.7275 - val_loss: -7.6612
# Epoch 180/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7000.3032 - loss: -7.8705 - val_log_likelihood_function: 6591.3086 - val_loss: -7.7561
# Epoch 181/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6159.0220 - loss: -7.0540 - val_log_likelihood_function: 6569.1616 - val_loss: -7.6151
# Epoch 182/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6955.4297 - loss: -7.8103 - val_log_likelihood_function: 6586.0684 - val_loss: -7.7730
# Epoch 183/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6189.0962 - loss: -7.3261 - val_log_likelihood_function: 6569.9785 - val_loss: -7.6679
# Epoch 184/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7011.6040 - loss: -7.8494 - val_log_likelihood_function: 6593.8540 - val_loss: -7.7643
# Epoch 185/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6197.0674 - loss: -7.2379 - val_log_likelihood_function: 6588.1357 - val_loss: -7.6700
# Epoch 186/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6986.7051 - loss: -7.8064 - val_log_likelihood_function: 6602.5322 - val_loss: -7.7612
# Epoch 187/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6205.4531 - loss: -7.2781 - val_log_likelihood_function: 6504.8940 - val_loss: -7.6344
# Epoch 188/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6923.6235 - loss: -7.7836 - val_log_likelihood_function: 6579.6162 - val_loss: -7.7669
# Epoch 189/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6218.0425 - loss: -7.2897 - val_log_likelihood_function: 6554.5796 - val_loss: -7.6471
# Epoch 190/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6916.9614 - loss: -7.8297 - val_log_likelihood_function: 6576.8848 - val_loss: -7.7635
# Epoch 191/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6227.4902 - loss: -7.2036 - val_log_likelihood_function: 6570.5312 - val_loss: -7.6779
# Epoch 192/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7053.4375 - loss: -7.8472 - val_log_likelihood_function: 6596.4751 - val_loss: -7.7623
# Epoch 193/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6214.8662 - loss: -7.2597 - val_log_likelihood_function: 6577.2959 - val_loss: -7.6823
# Epoch 194/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7000.7798 - loss: -7.7763 - val_log_likelihood_function: 6601.9199 - val_loss: -7.7669
# Epoch 195/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6279.0464 - loss: -7.3316 - val_log_likelihood_function: 6568.5039 - val_loss: -7.6622
# Epoch 196/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7035.0635 - loss: -7.8411 - val_log_likelihood_function: 6579.8750 - val_loss: -7.7538
# Epoch 197/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6283.5894 - loss: -7.3472 - val_log_likelihood_function: 6590.6323 - val_loss: -7.6986
# Epoch 198/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6939.0977 - loss: -7.8340 - val_log_likelihood_function: 6561.1714 - val_loss: -7.7671
# Epoch 199/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6100.0059 - loss: -7.2381 - val_log_likelihood_function: 6578.7417 - val_loss: -7.6694
# Epoch 200/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7000.9961 - loss: -7.7884 - val_log_likelihood_function: 6600.4414 - val_loss: -7.7612
# Epoch 201/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6342.0889 - loss: -7.3266 - val_log_likelihood_function: 6587.6382 - val_loss: -7.7007
# Epoch 202/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7002.4512 - loss: -7.7701 - val_log_likelihood_function: 6607.9634 - val_loss: -7.7648
# Epoch 203/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6260.4014 - loss: -7.2512 - val_log_likelihood_function: 6559.3462 - val_loss: -7.6821
# Epoch 204/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7012.1396 - loss: -7.9551 - val_log_likelihood_function: 6524.1914 - val_loss: -7.7574
# Epoch 205/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6309.1050 - loss: -7.3909 - val_log_likelihood_function: 6583.7095 - val_loss: -7.6848
# Epoch 206/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7050.4556 - loss: -7.8722 - val_log_likelihood_function: 6573.7773 - val_loss: -7.7683
# Epoch 207/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6275.1816 - loss: -7.2680 - val_log_likelihood_function: 6586.9883 - val_loss: -7.6834
# Epoch 208/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7051.2222 - loss: -7.8739 - val_log_likelihood_function: 6535.3643 - val_loss: -7.7115
# Epoch 209/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6266.6328 - loss: -7.3640 - val_log_likelihood_function: 6538.6533 - val_loss: -7.6360
# Epoch 210/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7038.9702 - loss: -7.8239 - val_log_likelihood_function: 6594.3784 - val_loss: -7.7411
# Epoch 211/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6337.5166 - loss: -7.3239 - val_log_likelihood_function: 6585.2505 - val_loss: -7.6767
# Epoch 212/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7071.5566 - loss: -7.9744 - val_log_likelihood_function: 6532.7300 - val_loss: -7.7529
# Epoch 213/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6265.3486 - loss: -7.3166 - val_log_likelihood_function: 6589.0664 - val_loss: -7.6908
# Epoch 214/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7045.6084 - loss: -7.8805 - val_log_likelihood_function: 6574.1660 - val_loss: -7.7634
# Epoch 215/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6356.5098 - loss: -7.3799 - val_log_likelihood_function: 6567.7427 - val_loss: -7.6560
# Epoch 216/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7065.6128 - loss: -7.9041 - val_log_likelihood_function: 6535.4092 - val_loss: -7.7287
# Epoch 217/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6008.4697 - loss: -7.0115 - val_log_likelihood_function: 6585.5132 - val_loss: -7.7003
# Epoch 218/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7060.8643 - loss: -7.8750 - val_log_likelihood_function: 6501.3403 - val_loss: -7.7101
# Epoch 219/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6160.6079 - loss: -7.2426 - val_log_likelihood_function: 6604.3213 - val_loss: -7.7126
# Epoch 220/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7062.5161 - loss: -7.9117 - val_log_likelihood_function: 6546.6602 - val_loss: -7.7372
# Epoch 221/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6292.2856 - loss: -7.2728 - val_log_likelihood_function: 6566.6992 - val_loss: -7.6653
# Epoch 222/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7049.7290 - loss: -7.8888 - val_log_likelihood_function: 6551.9551 - val_loss: -7.7592
# Epoch 223/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6277.9663 - loss: -7.3135 - val_log_likelihood_function: 6575.0537 - val_loss: -7.6619
# Epoch 224/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7043.8506 - loss: -7.9460 - val_log_likelihood_function: 6571.2217 - val_loss: -7.7659
# Epoch 225/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6359.3086 - loss: -7.3062 - val_log_likelihood_function: 6549.6655 - val_loss: -7.6498
# Epoch 226/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7006.4482 - loss: -7.8996 - val_log_likelihood_function: 6545.6348 - val_loss: -7.7298
# Epoch 227/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6151.8291 - loss: -7.1775 - val_log_likelihood_function: 6596.6982 - val_loss: -7.7075
# Epoch 228/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7088.9565 - loss: -7.9475 - val_log_likelihood_function: 6511.3345 - val_loss: -7.7308
# Epoch 229/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6386.4678 - loss: -7.4455 - val_log_likelihood_function: 6568.3530 - val_loss: -7.6859
# Epoch 230/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7108.2554 - loss: -7.9433 - val_log_likelihood_function: 6563.7041 - val_loss: -7.7678
# Epoch 231/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6275.8960 - loss: -7.3335 - val_log_likelihood_function: 6593.1519 - val_loss: -7.7028
# Epoch 232/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7061.3018 - loss: -7.8576 - val_log_likelihood_function: 6567.7964 - val_loss: -7.7423
# Epoch 233/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6286.5049 - loss: -7.3528 - val_log_likelihood_function: 6608.8311 - val_loss: -7.7163
# Epoch 234/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7089.2705 - loss: -8.0181 - val_log_likelihood_function: 6523.1812 - val_loss: -7.7260
# Epoch 235/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6334.3257 - loss: -7.3774 - val_log_likelihood_function: 6591.3789 - val_loss: -7.6653
# Epoch 236/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7089.6924 - loss: -7.8893 - val_log_likelihood_function: 6569.1099 - val_loss: -7.7503
# Epoch 237/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6362.5566 - loss: -7.4097 - val_log_likelihood_function: 6600.3057 - val_loss: -7.7072
# Epoch 238/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7104.9839 - loss: -7.9852 - val_log_likelihood_function: 6519.7300 - val_loss: -7.7257
# Epoch 239/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6288.6987 - loss: -7.3554 - val_log_likelihood_function: 6588.0996 - val_loss: -7.6842
# Epoch 240/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7133.9995 - loss: -7.9688 - val_log_likelihood_function: 6459.1558 - val_loss: -7.6645
# Epoch 241/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6330.5366 - loss: -7.3129 - val_log_likelihood_function: 6581.6914 - val_loss: -7.7074
# Epoch 242/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7082.5171 - loss: -7.9768 - val_log_likelihood_function: 6537.2822 - val_loss: -7.7636
# Epoch 243/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6383.3872 - loss: -7.3864 - val_log_likelihood_function: 6592.7905 - val_loss: -7.7102
# Epoch 244/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7105.6992 - loss: -8.0454 - val_log_likelihood_function: 6508.4961 - val_loss: -7.7205
# Epoch 245/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6373.9985 - loss: -7.4154 - val_log_likelihood_function: 6569.6631 - val_loss: -7.6834
# Epoch 246/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7123.6763 - loss: -8.0206 - val_log_likelihood_function: 6518.0723 - val_loss: -7.7015
# Epoch 247/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6326.7012 - loss: -7.3994 - val_log_likelihood_function: 6593.5972 - val_loss: -7.6864
# Epoch 248/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7124.4014 - loss: -7.9842 - val_log_likelihood_function: 6493.6377 - val_loss: -7.6832
# Epoch 249/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6257.8369 - loss: -7.3022 - val_log_likelihood_function: 6539.3970 - val_loss: -7.6595
# Epoch 250/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7079.0942 - loss: -7.9016 - val_log_likelihood_function: 6562.6182 - val_loss: -7.7558
# Epoch 251/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6352.9634 - loss: -7.4543 - val_log_likelihood_function: 6590.5654 - val_loss: -7.7094
# Epoch 252/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7103.7061 - loss: -7.8913 - val_log_likelihood_function: 6544.9043 - val_loss: -7.7516
# Epoch 253/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6373.3311 - loss: -7.4391 - val_log_likelihood_function: 6580.1465 - val_loss: -7.6762
# Epoch 254/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7128.8354 - loss: -7.9457 - val_log_likelihood_function: 6585.0063 - val_loss: -7.7648
# Epoch 255/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6292.4224 - loss: -7.3699 - val_log_likelihood_function: 6593.3091 - val_loss: -7.6990
# Epoch 256/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7150.2197 - loss: -7.9787 - val_log_likelihood_function: 6536.6953 - val_loss: -7.7516
# Epoch 257/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6396.0732 - loss: -7.4465 - val_log_likelihood_function: 6585.4038 - val_loss: -7.6977
# Epoch 258/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7128.0156 - loss: -7.9868 - val_log_likelihood_function: 6583.6074 - val_loss: -7.7716
# Epoch 259/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6410.2891 - loss: -7.4564 - val_log_likelihood_function: 6583.1675 - val_loss: -7.7093
# Epoch 260/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7157.3530 - loss: -7.9709 - val_log_likelihood_function: 6574.0107 - val_loss: -7.7660
# Epoch 261/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6433.2158 - loss: -7.3765 - val_log_likelihood_function: 6571.0679 - val_loss: -7.6830
# Epoch 262/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7165.1138 - loss: -8.0107 - val_log_likelihood_function: 6566.3452 - val_loss: -7.7727
# Epoch 263/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6439.5806 - loss: -7.4954 - val_log_likelihood_function: 6590.6958 - val_loss: -7.7221
# Epoch 264/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7138.2334 - loss: -8.0098 - val_log_likelihood_function: 6508.6655 - val_loss: -7.7291
# Epoch 265/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6437.7520 - loss: -7.4627 - val_log_likelihood_function: 6551.9297 - val_loss: -7.6880
# Epoch 266/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7133.9692 - loss: -7.9637 - val_log_likelihood_function: 6531.6743 - val_loss: -7.7445
# Epoch 267/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6410.8052 - loss: -7.4763 - val_log_likelihood_function: 6593.2197 - val_loss: -7.6833
# Epoch 268/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7126.7051 - loss: -7.9999 - val_log_likelihood_function: 6544.3369 - val_loss: -7.7356
# Epoch 269/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6418.0054 - loss: -7.4647 - val_log_likelihood_function: 6528.9512 - val_loss: -7.6806
# Epoch 270/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7141.4355 - loss: -8.0088 - val_log_likelihood_function: 6525.8252 - val_loss: -7.7482
# Epoch 271/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6344.7427 - loss: -7.4248 - val_log_likelihood_function: 6557.4502 - val_loss: -7.6832
# Epoch 272/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7153.8853 - loss: -7.9655 - val_log_likelihood_function: 6585.4282 - val_loss: -7.7618
# Epoch 273/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6381.8950 - loss: -7.4381 - val_log_likelihood_function: 6571.3643 - val_loss: -7.6933
# Epoch 274/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7158.0781 - loss: -8.0634 - val_log_likelihood_function: 6475.0879 - val_loss: -7.7099
# Epoch 275/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6410.5532 - loss: -7.3619 - val_log_likelihood_function: 6572.7451 - val_loss: -7.6804
# Epoch 276/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7155.4194 - loss: -7.9265 - val_log_likelihood_function: 6516.8530 - val_loss: -7.7327
# Epoch 277/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6435.6836 - loss: -7.3958 - val_log_likelihood_function: 6526.9380 - val_loss: -7.6637
# Epoch 278/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7145.5215 - loss: -8.0667 - val_log_likelihood_function: 6509.4170 - val_loss: -7.7421
# Epoch 279/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6351.0229 - loss: -7.3590 - val_log_likelihood_function: 6582.2637 - val_loss: -7.6951
# Epoch 280/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7176.1484 - loss: -8.0321 - val_log_likelihood_function: 6543.7656 - val_loss: -7.7561
# Epoch 281/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6436.4946 - loss: -7.4802 - val_log_likelihood_function: 6589.5571 - val_loss: -7.6932
# Epoch 282/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7164.9922 - loss: -7.9571 - val_log_likelihood_function: 6555.0283 - val_loss: -7.7537
# Epoch 283/500
# ...
# Epoch 408/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7284.2192 - loss: -8.1300 - val_log_likelihood_function: 6475.2129 - val_loss: -7.7188
# Epoch 409/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6574.3320 - loss: -7.5970 - val_log_likelihood_function: 6534.2437 - val_loss: -7.6856
# Epoch 410/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7274.1528 - loss: -8.1600 - val_log_likelihood_function: 6507.2915 - val_loss: -7.7398
# Epoch 411/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6548.1948 - loss: -7.6165 - val_log_likelihood_function: 6541.3018 - val_loss: -7.6943
# Epoch 412/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7283.6592 - loss: -8.1221 - val_log_likelihood_function: 6467.6968 - val_loss: -7.7308
# Epoch 413/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6573.2725 - loss: -7.6087 - val_log_likelihood_function: 6482.7651 - val_loss: -7.6374
# Epoch 414/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7286.5913 - loss: -8.1629 - val_log_likelihood_function: 6441.2437 - val_loss: -7.6738
# Epoch 415/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6597.0410 - loss: -7.6276 - val_log_likelihood_function: 6473.4663 - val_loss: -7.6359
# Epoch 416/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7274.6079 - loss: -8.1364 - val_log_likelihood_function: 6414.0703 - val_loss: -7.6572
# Epoch 417/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6585.9932 - loss: -7.6571 - val_log_likelihood_function: 6477.3237 - val_loss: -7.6547
# Epoch 418/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7262.8906 - loss: -8.1374 - val_log_likelihood_function: 6456.4189 - val_loss: -7.7120
# Epoch 419/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6569.7817 - loss: -7.5878 - val_log_likelihood_function: 6509.0776 - val_loss: -7.6496
# Epoch 420/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7279.0171 - loss: -8.1314 - val_log_likelihood_function: 6470.0117 - val_loss: -7.7193
# Epoch 421/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6570.8174 - loss: -7.5956 - val_log_likelihood_function: 6524.4233 - val_loss: -7.6719
# Epoch 422/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7298.7476 - loss: -8.1624 - val_log_likelihood_function: 6501.8262 - val_loss: -7.7307
# Epoch 423/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6608.3594 - loss: -7.6064 - val_log_likelihood_function: 6520.1929 - val_loss: -7.6739
# Epoch 424/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7294.0903 - loss: -8.1682 - val_log_likelihood_function: 6441.3921 - val_loss: -7.7050
# Epoch 425/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6551.1118 - loss: -7.5744 - val_log_likelihood_function: 6502.8003 - val_loss: -7.6601
# Epoch 426/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7286.3706 - loss: -8.1642 - val_log_likelihood_function: 6438.2559 - val_loss: -7.7054
# Epoch 427/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6550.9185 - loss: -7.6338 - val_log_likelihood_function: 6506.1494 - val_loss: -7.6789
# Epoch 428/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7278.2100 - loss: -8.1562 - val_log_likelihood_function: 6395.3047 - val_loss: -7.6784
# Epoch 429/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6553.6050 - loss: -7.6232 - val_log_likelihood_function: 6521.4263 - val_loss: -7.6902
# Epoch 430/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7273.6050 - loss: -8.1830 - val_log_likelihood_function: 6431.1973 - val_loss: -7.7005
# Epoch 431/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6599.6987 - loss: -7.6489 - val_log_likelihood_function: 6489.6870 - val_loss: -7.6616
# Epoch 432/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7276.0161 - loss: -8.1209 - val_log_likelihood_function: 6455.8750 - val_loss: -7.7435
# Epoch 433/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6597.0732 - loss: -7.6631 - val_log_likelihood_function: 6497.8491 - val_loss: -7.6620
# Epoch 434/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7304.3584 - loss: -8.1571 - val_log_likelihood_function: 6497.6187 - val_loss: -7.7468
# Epoch 435/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6606.8516 - loss: -7.6367 - val_log_likelihood_function: 6495.2222 - val_loss: -7.6739
# Epoch 436/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7273.3003 - loss: -8.1691 - val_log_likelihood_function: 6463.7407 - val_loss: -7.7254
# Epoch 437/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6570.2720 - loss: -7.6051 - val_log_likelihood_function: 6526.8320 - val_loss: -7.7011
# Epoch 438/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7285.2056 - loss: -8.1702 - val_log_likelihood_function: 6489.8867 - val_loss: -7.7597
# Epoch 439/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6626.9561 - loss: -7.6352 - val_log_likelihood_function: 6522.2910 - val_loss: -7.6768
# Epoch 440/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7294.8550 - loss: -8.1635 - val_log_likelihood_function: 6449.0552 - val_loss: -7.7380
# Epoch 441/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6594.9858 - loss: -7.6254 - val_log_likelihood_function: 6505.6768 - val_loss: -7.6782
# Epoch 442/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7302.2095 - loss: -8.2175 - val_log_likelihood_function: 6409.0176 - val_loss: -7.6981
# Epoch 443/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6546.1689 - loss: -7.6470 - val_log_likelihood_function: 6490.3682 - val_loss: -7.6619
# Epoch 444/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7292.7622 - loss: -8.1732 - val_log_likelihood_function: 6467.8999 - val_loss: -7.7385
# Epoch 445/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6588.2896 - loss: -7.6445 - val_log_likelihood_function: 6495.5273 - val_loss: -7.6657
# Epoch 446/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7295.4707 - loss: -8.1299 - val_log_likelihood_function: 6450.1626 - val_loss: -7.7140
# Epoch 447/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6584.0068 - loss: -7.6056 - val_log_likelihood_function: 6550.7891 - val_loss: -7.6994
# Epoch 448/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7301.9375 - loss: -8.1383 - val_log_likelihood_function: 6465.6353 - val_loss: -7.7251
# Epoch 449/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6611.3989 - loss: -7.6204 - val_log_likelihood_function: 6500.6758 - val_loss: -7.6510
# Epoch 450/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7302.5596 - loss: -8.1588 - val_log_likelihood_function: 6431.6240 - val_loss: -7.6862
# Epoch 451/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6629.1641 - loss: -7.6494 - val_log_likelihood_function: 6482.2812 - val_loss: -7.6618
# Epoch 452/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7295.1436 - loss: -8.1886 - val_log_likelihood_function: 6397.6689 - val_loss: -7.7005
# Epoch 453/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6557.0757 - loss: -7.6321 - val_log_likelihood_function: 6487.9414 - val_loss: -7.6636
# Epoch 454/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7285.6689 - loss: -8.1809 - val_log_likelihood_function: 6427.5088 - val_loss: -7.6929
# Epoch 455/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6567.7646 - loss: -7.6554 - val_log_likelihood_function: 6484.9541 - val_loss: -7.6516
# Epoch 456/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7299.4009 - loss: -8.1148 - val_log_likelihood_function: 6502.0776 - val_loss: -7.7463
# Epoch 457/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6621.2700 - loss: -7.6699 - val_log_likelihood_function: 6468.4258 - val_loss: -7.6414
# Epoch 458/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7290.1494 - loss: -8.1340 - val_log_likelihood_function: 6506.1270 - val_loss: -7.7485
# Epoch 459/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6608.4521 - loss: -7.6494 - val_log_likelihood_function: 6498.9023 - val_loss: -7.6661
# Epoch 460/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7304.5249 - loss: -8.1808 - val_log_likelihood_function: 6463.6577 - val_loss: -7.7096
# Epoch 461/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6554.0566 - loss: -7.6655 - val_log_likelihood_function: 6424.9878 - val_loss: -7.5987
# Epoch 462/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7281.4380 - loss: -8.1676 - val_log_likelihood_function: 6463.3403 - val_loss: -7.7241
# Epoch 463/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6595.4858 - loss: -7.6559 - val_log_likelihood_function: 6476.0806 - val_loss: -7.6581
# Epoch 464/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7305.1929 - loss: -8.1503 - val_log_likelihood_function: 6431.5166 - val_loss: -7.7146
# Epoch 465/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6572.1152 - loss: -7.5840 - val_log_likelihood_function: 6505.9658 - val_loss: -7.6689
# Epoch 466/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7306.9907 - loss: -8.1717 - val_log_likelihood_function: 6455.0889 - val_loss: -7.7279
# Epoch 467/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6633.6191 - loss: -7.6634 - val_log_likelihood_function: 6476.6265 - val_loss: -7.6559
# Epoch 468/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7294.6431 - loss: -8.1563 - val_log_likelihood_function: 6462.6396 - val_loss: -7.7350
# Epoch 469/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6614.3750 - loss: -7.6567 - val_log_likelihood_function: 6467.2905 - val_loss: -7.6444
# Epoch 470/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7297.4912 - loss: -8.1746 - val_log_likelihood_function: 6458.2983 - val_loss: -7.7365
# Epoch 471/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6601.2578 - loss: -7.6438 - val_log_likelihood_function: 6491.1694 - val_loss: -7.6699
# Epoch 472/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7306.3457 - loss: -8.1554 - val_log_likelihood_function: 6457.4771 - val_loss: -7.7491
# Epoch 473/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6623.4434 - loss: -7.6327 - val_log_likelihood_function: 6498.0815 - val_loss: -7.6824
# Epoch 474/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7308.3589 - loss: -8.1824 - val_log_likelihood_function: 6421.0825 - val_loss: -7.7066
# Epoch 475/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6605.4243 - loss: -7.6641 - val_log_likelihood_function: 6481.9092 - val_loss: -7.6702
# Epoch 476/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7298.4233 - loss: -8.1500 - val_log_likelihood_function: 6433.4600 - val_loss: -7.7223
# Epoch 477/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6559.1450 - loss: -7.6376 - val_log_likelihood_function: 6496.2090 - val_loss: -7.6682
# Epoch 478/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7303.5327 - loss: -8.1708 - val_log_likelihood_function: 6442.3315 - val_loss: -7.7210
# Epoch 479/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6587.5366 - loss: -7.6833 - val_log_likelihood_function: 6497.8848 - val_loss: -7.6808
# Epoch 480/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7312.5190 - loss: -8.1867 - val_log_likelihood_function: 6428.3833 - val_loss: -7.6972
# Epoch 481/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6637.1104 - loss: -7.6898 - val_log_likelihood_function: 6501.7573 - val_loss: -7.6793
# Epoch 482/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7301.8560 - loss: -8.2030 - val_log_likelihood_function: 6413.2837 - val_loss: -7.7012
# Epoch 483/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6603.4102 - loss: -7.6825 - val_log_likelihood_function: 6487.2402 - val_loss: -7.6712
# Epoch 484/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7299.3472 - loss: -8.1941 - val_log_likelihood_function: 6402.6079 - val_loss: -7.6829
# Epoch 485/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6602.1353 - loss: -7.6394 - val_log_likelihood_function: 6470.7261 - val_loss: -7.6596
# Epoch 486/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7309.2798 - loss: -8.1563 - val_log_likelihood_function: 6409.0615 - val_loss: -7.7206
# Epoch 487/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6591.7798 - loss: -7.6122 - val_log_likelihood_function: 6478.7393 - val_loss: -7.6602
# Epoch 488/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7303.6582 - loss: -8.1684 - val_log_likelihood_function: 6449.7339 - val_loss: -7.7209
# Epoch 489/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6619.4253 - loss: -7.6624 - val_log_likelihood_function: 6484.5220 - val_loss: -7.6448
# Epoch 490/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7290.3818 - loss: -8.1725 - val_log_likelihood_function: 6444.9692 - val_loss: -7.7115
# Epoch 491/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6640.4160 - loss: -7.6496 - val_log_likelihood_function: 6500.3691 - val_loss: -7.6930
# Epoch 492/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7317.6797 - loss: -8.1803 - val_log_likelihood_function: 6437.1895 - val_loss: -7.7107
# Epoch 493/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6610.0854 - loss: -7.6896 - val_log_likelihood_function: 6493.0273 - val_loss: -7.6867
# Epoch 494/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7307.8530 - loss: -8.1757 - val_log_likelihood_function: 6433.5854 - val_loss: -7.7120
# Epoch 495/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6639.3252 - loss: -7.6802 - val_log_likelihood_function: 6520.3433 - val_loss: -7.6926
# Epoch 496/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7312.7275 - loss: -8.2001 - val_log_likelihood_function: 6438.1694 - val_loss: -7.7217
# Epoch 497/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6604.4019 - loss: -7.6791 - val_log_likelihood_function: 6478.2002 - val_loss: -7.6562
# Epoch 498/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 7314.1577 - loss: -8.1578 - val_log_likelihood_function: 6429.8711 - val_loss: -7.7141
# Epoch 499/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6636.2861 - loss: -7.6806 - val_log_likelihood_function: 6484.6187 - val_loss: -7.6705
# Epoch 500/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 7311.0815 - loss: -8.1668 - val_log_likelihood_function: 6436.7388 - val_loss: -7.7350
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6930.3296 - loss: -7.7665
# Test loss (Log-Likelihood): -8.061001777648926
# Test log-likelihood: 7017.1044921875

# %%
# prompt: đưa ra giá trị loss nhỏ nhất, ở epoch nào

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'history' is the training history object from model.fit
min_loss = np.min(history.history['val_loss'])
min_loss_epoch = np.argmin(history.history['loss'])

print(f"Minimum val loss: {min_loss} at epoch {min_loss_epoch}")
# Out:
# Minimum val loss: -7.795030117034912 at epoch 441

# %%
# prompt: vẽ biểu đồ loss

import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# prompt: đưa ra giá trị dự đoán của mô hình cho test_gen

# Assuming 'model' and 'test_gen' are defined as in the previous code.
# Get predictions for the test data
predictions = model.predict(x_test)

# Print the predictions
predictions
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.00845251],
#        [0.0086195 ],
#        [0.00852099],
#        [0.00932832],
#        [0.00954747],
#        [0.00902323],
#        [0.00929848],
#        [0.00955051],
#        [0.00831576],
#        [0.007928  ],
#        [0.00790079],
#        [0.00795158],
#        [0.00827961],
#        [0.00890537],
#        [0.00849902],
#        [0.00823281],
#        [0.00818655],
#        [0.00783496],
#        [0.00830447],
#        [0.00828873],
#        [0.00834082],
#        [0.00845801],
#        [0.00849374],
#        [0.0132512 ],
#        [0.01271452],
#        [0.00970657],
#        [0.01009106],
#        [0.00964077],
#        [0.01030078],
#        [0.00969092],
#        [0.00900564],
#        [0.01438969],
#        [0.01047726],
#        [0.01077582],
#        [0.01014056],
#        [0.01057774],
#        [0.01541283],
#        [0.01330687],
#        [0.01638486],
#        [0.01972621],
#        [0.0150161 ],
#        [0.02991333],
#        [0.02270514],
#        [0.014585  ],
#        [0.02245427],
#        [0.02404712],
#        [0.01830406],
#        [0.02717638],
#        [0.01342825],
#        [0.01406422],
#        [0.01445574],
#        [0.00929886],
#        [0.00862486],
#        [0.01002459],
#        [0.01024542],
#        [0.01739705],
#        [0.01947192],
#        [0.0243681 ],
#        [0.01457381],
#        [0.01284614],
#        [0.01236573],
#        [0.01007398],
#        [0.00857235],
#        [0.01185855],
#        [0.00922669],
#        [0.01238153],
#        [0.01731387],
#        [0.01550391],
#        [0.01220629],
#        [0.02287902],
#        [0.01722793],
#        [0.01674831],
#        [0.02323142],
#        [0.01322213],
#        [0.01364337],
#        [0.01093758],
#        [0.00798712],
#        [0.00940719],
#        [0.00853034],
#        [0.01018218],
#        [0.0084867 ],
#        [0.0147872 ],
#        [0.01495138],
#        [0.0124313 ],
#        [0.01048527],
#        [0.01999523],
#        [0.01472558],
#        [0.01836683],
#        [0.01717595],
#        [0.01635167],
#        [0.01348266],
#        [0.01312968],
#        [0.0140321 ],
#        [0.01055484],
#        [0.00917665],
#        [0.00926469],
#        [0.01119162],
#        [0.01040645],
#        [0.01022333],
#        [0.01051628],
#        [0.01067309],
#        [0.01930617],
#        [0.01580746],
#        [0.00959111],
#        [0.01019164],
#        [0.00932397],
#        [0.01078442],
#        [0.00892894],
#        [0.00889351],
#        [0.00836331],
#        [0.00888419],
#        [0.01125968],
#        [0.00933036],
#        [0.00868933],
#        [0.0100693 ],
#        [0.00966522],
#        [0.00957677],
#        [0.00849611],
#        [0.00862717],
#        [0.00923572],
#        [0.00938003],
#        [0.01003041],
#        [0.01383704],
#        [0.01328146],
#        [0.01157625],
#        [0.00998681],
#        [0.01232378],
#        [0.01117815],
#        [0.01119432],
#        [0.01021761],
#        [0.01259395],
#        [0.01240491],
#        [0.01111187],
#        [0.00826294],
#        [0.00916501],
#        [0.00984157],
#        [0.00857468],
#        [0.01131912],
#        [0.0086238 ],
#        [0.01133091],
#        [0.01424136],
#        [0.01285332],
#        [0.01217156],
#        [0.0100929 ],
#        [0.0108773 ],
#        [0.01037524],
#        [0.00868608],
#        [0.00835669],
#        [0.00887235],
#        [0.00797529],
#        [0.00858214],
#        [0.00992512],
#        [0.00884953],
#        [0.00997024],
#        [0.00950355],
#        [0.0116627 ],
#        [0.01115819],
#        [0.00856554],
#        [0.00871039],
#        [0.00904535],
#        [0.00818608],
#        [0.00811224],
#        [0.00830991],
#        [0.00801103],
#        [0.00818166],
#        [0.0093773 ],
#        [0.00810716],
#        [0.00817715],
#        [0.0083921 ],
#        [0.00872936],
#        [0.00896794],
#        [0.00874823],
#        [0.00887926],
#        [0.00889456],
#        [0.01024834],
#        [0.00919608],
#        [0.00896331],
#        [0.00958287],
#        [0.00943929],
#        [0.0098109 ],
#        [0.00939151],
#        [0.00948272],
#        [0.00904666],
#        [0.00892442],
#        [0.00801861],
#        [0.00854225],
#        [0.0082538 ],
#        [0.00793557],
#        [0.00846603],
#        [0.00780824],
#        [0.00796114],
#        [0.00832615],
#        [0.00804702],
#        [0.00818578],
#        [0.00818852],
#        [0.00892035],
#        [0.00830303],
#        [0.00802191],
#        [0.00823931],
#        [0.00850985],
#        [0.00849171],
#        [0.0083545 ],
#        [0.00796754],
#        [0.00787682],
#        [0.0078264 ],
#        [0.00792159],
#        [0.00798277],
#        [0.00788015],
#        [0.00833776],
#        [0.0080963 ],
#        [0.00829985],
#        [0.00915442],
#        [0.00826446],
#        [0.00822265],
#        [0.00831523],
#        [0.00871034],
#        [0.00847753],
#        [0.00938877],
#        [0.00847941],
#        [0.00828646],
#        [0.00802879],
#        [0.00788642],
#        [0.00773673],
#        [0.00778304],
#        [0.00798132],
#        [0.00920541],
#        [0.0089462 ],
#        [0.00925609],
#        [0.00828629],
#        [0.00798928],
#        [0.00845848],
#        [0.00880366],
#        [0.00788609],
#        [0.00805474],
#        [0.00785351],
#        [0.00847271],
#        [0.00814892],
#        [0.00833318],
#        [0.00812321],
#        [0.00826758],
#        [0.00892811],
#        [0.00881565],
#        [0.00805259],
#        [0.00828484],
#        [0.00820907],
#        [0.00802696],
#        [0.00859223],
#        [0.00841163],
#        [0.00824329],
#        [0.00876526],
#        [0.00858239],
#        [0.00917906],
#        [0.00849421],
#        [0.00813121],
#        [0.00811224],
#        [0.00888789],
#        [0.00921612],
#        [0.0083799 ],
#        [0.00851743],
#        [0.00881417],
#        [0.00834738],
#        [0.02014168],
#        [0.01377564],
#        [0.01267344],
#        [0.01382417],
#        [0.01181965],
#        [0.01239827],
#        [0.01018923],
#        [0.00887232],
#        [0.00914124],
#        [0.01020817],
#        [0.00847393],
#        [0.0086866 ],
#        [0.0086186 ],
#        [0.00901803],
#        [0.00939437],
#        [0.01059727],
#        [0.00890474],
#        [0.00993367],
#        [0.01095269],
#        [0.0104294 ],
#        [0.01023733],
#        [0.00812705],
#        [0.01046665],
#        [0.01099251],
#        [0.01984883],
#        [0.01886049],
#        [0.01253384],
#        [0.01337414],
#        [0.01360388],
#        [0.01179835],
#        [0.01753137],
#        [0.00980204],
#        [0.01328903],
#        [0.01043181],
#        [0.00940363],
#        [0.00851491],
#        [0.00834447],
#        [0.00820004],
#        [0.00777952],
#        [0.00978317],
#        [0.01183025],
#        [0.01252499],
#        [0.01486474],
#        [0.01307406],
#        [0.0130281 ],
#        [0.01214847],
#        [0.01049114],
#        [0.02087342],
#        [0.01232681],
#        [0.01528764],
#        [0.01835931],
#        [0.01296739],
#        [0.0116859 ],
#        [0.01096612],
#        [0.00869378],
#        [0.00966551],
#        [0.01210789],
#        [0.01102674],
#        [0.01031966],
#        [0.01017309],
#        [0.01158275],
#        [0.01059314],
#        [0.00856416],
#        [0.01069196],
#        [0.01110336],
#        [0.00916292],
#        [0.00851683],
#        [0.01178689],
#        [0.01173471],
#        [0.0102339 ],
#        [0.00851238],
#        [0.00839689],
#        [0.00999019],
#        [0.00939065],
#        [0.00814547],
#        [0.0088224 ],
#        [0.00828184],
#        [0.00807588],
#        [0.00830441],
#        [0.00856225],
#        [0.00833022],
#        [0.0092462 ],
#        [0.0097821 ],
#        [0.01050905],
#        [0.01092996],
#        [0.01040052],
#        [0.00959585],
#        [0.00922935],
#        [0.00832478],
#        [0.00811742],
#        [0.00837958],
#        [0.00799179],
#        [0.00784312],
#        [0.00807074],
#        [0.00835188],
#        [0.00871318],
#        [0.00816201],
#        [0.00855648],
#        [0.008612  ],
#        [0.00809013],
#        [0.00844418],
#        [0.00835542],
#        [0.00871506],
#        [0.00912423],
#        [0.00874154],
#        [0.00806782],
#        [0.00799012],
#        [0.00793935],
#        [0.00776654],
#        [0.00794782],
#        [0.00813674],
#        [0.00845863],
#        [0.00850111],
#        [0.00839155],
#        [0.00840681],
#        [0.00919552],
#        [0.00916591],
#        [0.00815663],
#        [0.00786902],
#        [0.00784142],
#        [0.00796748],
#        [0.00785597],
#        [0.00807869],
#        [0.00838406],
#        [0.00844987],
#        [0.00845412],
#        [0.0086787 ],
#        [0.00994156],
#        [0.00986496],
#        [0.00843954],
#        [0.00845164],
#        [0.00802048],
#        [0.00834131],
#        [0.00795045],
#        [0.00828386],
#        [0.00876635],
#        [0.00875326],
#        [0.01015515],
#        [0.01088662],
#        [0.01040764],
#        [0.00847225],
#        [0.00826338],
#        [0.0080577 ],
#        [0.00955325],
#        [0.00881442],
#        [0.00782891],
#        [0.00905815],
#        [0.0079318 ],
#        [0.00806157],
#        [0.00952234],
#        [0.00819157],
#        [0.00814728],
#        [0.00848774],
#        [0.00890896],
#        [0.0094663 ],
#        [0.00983745],
#        [0.00938883],
#        [0.01038109],
#        [0.01119195],
#        [0.00927282],
#        [0.0094251 ],
#        [0.00946237],
#        [0.00806249],
#        [0.019164  ],
#        [0.01253925],
#        [0.01471163],
#        [0.01862541],
#        [0.01396187],
#        [0.01568528],
#        [0.01478257],
#        [0.00977984],
#        [0.0101079 ],
#        [0.01063962],
#        [0.00850804],
#        [0.00880221],
#        [0.00920517],
#        [0.0083382 ],
#        [0.00910528],
#        [0.00976944],
#        [0.00875076],
#        [0.00886264],
#        [0.00875022],
#        [0.00882394],
#        [0.00801376],
#        [0.00788757],
#        [0.00789288],
#        [0.00872052],
#        [0.00865704],
#        [0.0097711 ],
#        [0.00990426],
#        [0.00902532],
#        [0.00869154],
#        [0.00872483],
#        [0.00857116],
#        [0.00847826],
#        [0.00818244],
#        [0.00789184],
#        [0.00798713],
#        [0.00818045],
#        [0.00796934],
#        [0.00855869],
#        [0.00839927],
#        [0.00809217],
#        [0.01008203],
#        [0.00929655],
#        [0.00882933],
#        [0.0087572 ],
#        [0.00828003],
#        [0.0090019 ],
#        [0.01122915],
#        [0.01034956],
#        [0.00912821],
#        [0.00967347],
#        [0.01032512],
#        [0.01018082],
#        [0.00842058],
#        [0.00827263],
#        [0.00796014],
#        [0.00797299],
#        [0.0079396 ],
#        [0.0082153 ],
#        [0.00870452],
#        [0.00842521],
#        [0.00913446],
#        [0.00883355],
#        [0.0085285 ],
#        [0.00953042],
#        [0.00944838],
#        [0.00918642],
#        [0.0103394 ],
#        [0.01248042],
#        [0.0111555 ],
#        [0.01107171],
#        [0.00955234],
#        [0.00963316],
#        [0.00884007],
#        [0.00814437],
#        [0.01070586],
#        [0.00852755],
#        [0.0173718 ],
#        [0.01379116],
#        [0.00975582],
#        [0.0107059 ],
#        [0.01062616],
#        [0.00847576],
#        [0.00850627],
#        [0.00881366],
#        [0.00903697],
#        [0.0106658 ],
#        [0.0084905 ],
#        [0.00825656],
#        [0.00944431],
#        [0.00845813],
#        [0.00908028],
#        [0.00904911],
#        [0.00864616],
#        [0.00949811],
#        [0.00939451],
#        [0.00872894],
#        [0.00865833],
#        [0.00920864],
#        [0.00844027],
#        [0.0090816 ],
#        [0.0100825 ],
#        [0.00977785],
#        [0.00944963],
#        [0.00916243],
#        [0.01034219],
#        [0.00930641],
#        [0.00822132],
#        [0.00771847],
#        [0.0077566 ],
#        [0.00806319],
#        [0.00823609],
#        [0.00818179],
#        [0.00797164],
#        [0.00828597],
#        [0.00850422],
#        [0.00835299],
#        [0.00846994],
#        [0.00909572],
#        [0.00961102],
#        [0.00962606],
#        [0.00901627],
#        [0.00816846],
#        [0.00798741],
#        [0.00778644],
#        [0.00768878],
#        [0.00819505],
#        [0.00813744],
#        [0.00810226],
#        [0.00820635],
#        [0.00850577],
#        [0.00923158],
#        [0.00887775],
#        [0.01008991],
#        [0.01010088],
#        [0.00994478],
#        [0.00903449],
#        [0.00880637],
#        [0.0081507 ],
#        [0.00882135],
#        [0.00902534],
#        [0.00853006],
#        [0.00814379],
#        [0.00816392],
#        [0.0082529 ],
#        [0.00890958],
#        [0.00853964],
#        [0.00828099],
#        [0.01022806],
#        [0.01151305],
#        [0.01095434],
#        [0.0120197 ],
#        [0.0101672 ],
#        [0.00887388],
#        [0.0087974 ],
#        [0.00789078],
#        [0.00780571],
#        [0.00815495],
#        [0.00809609],
#        [0.00801532],
#        [0.00812586],
#        [0.00852063],
#        [0.00873149],
#        [0.00973646],
#        [0.00802935],
#        [0.00794492],
#        [0.00796096],
#        [0.00810082],
#        [0.00843757],
#        [0.00883954]], dtype=float32)

# %%
predictions.shape
# Out:
# (593, 1)

# %%
r_t = tf.cast(y_test, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
sigma_t = tf.cast(predictions, dtype=tf.float32) # Cast y_pred to tf.float32 as well
# Constants
import math
pi=math.pi

# Calculate log-likelihood
# Use tf.math.log, tf.math.square, and tf.math.reduce_sum
log_L = np.sum(-0.5 * np.log(2 *pi) - np.log(sigma_t) - (r_t**2) / (2 * sigma_t**2))
log_L
# Out:
# 1044151.1

# %%
# prompt: vẽ biểu đồ chỉ có predictions

import matplotlib.pyplot as plt

# Assuming 'predictions' is already defined from your model.predict call
# and has the correct shape (number of test samples, 1)

plt.figure(figsize=(10, 6))
plt.plot(predictions, label='Predictions')
plt.title('Bitcoin Price Predictions')
plt.ylabel('Predicted Return')
plt.xlabel('Time Step')
plt.legend()
plt.grid(True)
plt.show()
