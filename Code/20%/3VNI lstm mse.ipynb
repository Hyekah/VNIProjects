# %%
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
from tqdm.notebook import tqdm
from datetime import timedelta
import matplotlib.pyplot as plt
from IPython.display import Image
import plotly.graph_objects as go
from keras.utils import plot_model
from keras.models import Sequential
from IPython.display import Image, display
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from tensorflow.keras.layers import Embedding, SpatialDropout1D, Bidirectional, LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/1VNIndex.xlsx' # Đường dẫn đã được cập nhật
df = pd.read_excel(file_path)
# Out:
# Mounted at /content/drive

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#              Price
# Date
# 2000-07-31  101.55
# 2000-08-02  103.38
# 2000-08-04  105.20
# 2000-08-07  106.92
# 2000-08-09  108.64

# %%
return_series=np.log(df['Price']/df['Price'].shift(1))

# %%
return_series = return_series.dropna()

# %%
return_series
# Out:
# Date
# 2000-08-02    0.017860
# 2000-08-04    0.017452
# 2000-08-07    0.016218
# 2000-08-09    0.015959
# 2000-08-11    0.015708
#                 ...
# 2024-12-10   -0.001390
# 2024-12-11   -0.002527
# 2024-12-12   -0.001191
# 2024-12-13   -0.003779
# 2024-12-16    0.000966
# Name: Price, Length: 5931, dtype: float64

# %%
r_t=return_series.values.reshape(5931,1)

# %%
# prompt: đưa ra bảng mô tả thống kê, kurtosis, jacque cho r_t

import pandas as pd
import numpy as np

# Assuming 'return_series' and 'r_t' are defined as in the previous code
# ... (your existing code) ...

# Calculate descriptive statistics
r_t_series = pd.Series(r_t.flatten()) # Convert r_t to a pandas Series for easier calculations
description = r_t_series.describe()

# Calculate kurtosis and skewness (Fisher's definition)
kurtosis = r_t_series.kurtosis()
skewness = r_t_series.skew()


# Print the results
print("Descriptive Statistics:")
print(description)
print("\nKurtosis:", kurtosis)
print("\nSkewness (Fisher):", skewness)

# Create a summary table
summary_table = pd.DataFrame({
    'Statistic': ['Count', 'Mean', 'Standard Deviation', 'Min', '25%', '50%', '75%', 'Max', 'Kurtosis', 'Skewness'],
    'Value': [description['count'], description['mean'], description['std'], description['min'], description['25%'],
              description['50%'], description['75%'], description['max'], kurtosis, skewness]
})

print("\nSummary Table:")
summary_table
# Out:
# Descriptive Statistics:
# count    5931.000000
# mean        0.000425
# std         0.014439
# min        -0.076557
# 25%        -0.005534
# 50%         0.000607
# 75%         0.007378
# max         0.066561
# dtype: float64
#
# Kurtosis: 3.4097427278606807
#
# Skewness (Fisher): -0.3953987594767815
#
# Summary Table:
#             Statistic        Value
# 0               Count  5931.000000
# 1                Mean     0.000425
# 2  Standard Deviation     0.014439
# 3                 Min    -0.076557
# 4                 25%    -0.005534
# 5                 50%     0.000607
# 6                 75%     0.007378
# 7                 Max     0.066561
# 8            Kurtosis     3.409743
# 9            Skewness    -0.395399

# %%
# prompt: đưa ra kết quả jacque bera test cho r_t

import numpy as np
import pandas as pd
from scipy.stats import jarque_bera

# Assuming 'r_t' is defined as in the previous code
# ... (your existing code) ...

# Perform Jarque-Bera test
jb_statistic, p_value = jarque_bera(r_t.flatten())

print("\nJarque-Bera Test:")
print("Statistic:", jb_statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The data does not follow a normal distribution.")
else:
    print("Fail to reject the null hypothesis: The data may follow a normal distribution.")
# Out:
# Jarque-Bera Test:
# Statistic: 3021.0807048199413
# p-value: 0.0
# Reject the null hypothesis: The data does not follow a normal distribution.

# %%
from matplotlib import pyplot as plt
plt.plot(r_t)
plt.show()

# %%
plt.plot(r_t[:42])
plt.xticks(rotation=45)
plt.show()

# %%
r_t1 = pd.Series(r_t.flatten())
vol=r_t1.rolling(window=21,min_periods=1).std()
vol1=vol.fillna(vol.mean())
vol2=vol1.values.reshape(5931,1)
vol2
# Out:
# array([[0.01198883],
#        [0.00028882],
#        [0.00085521],
#        ...,
#        [0.00766237],
#        [0.00722134],
#        [0.00667567]])

# %%
seq_len = 11
sequence = []
for index in range(len(vol2) - seq_len + 1):
    sequence.append(vol2[index: index + seq_len])
sequence = np.array(sequence)
print(sequence.shape)
# Out:
# (5921, 11, 1)

# %%
def split_data(sequence):
    train_data, test_data = train_test_split(sequence, test_size=0.4, shuffle=False,random_state=42)
    val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=False,random_state=42)
    return train_data, val_data, test_data

# %%
train_data, val_data, test_data = split_data(sequence)
print("Train:", train_data.shape, "Validation:", val_data.shape, "Test:", test_data.shape)
# Out:
# Train: (3552, 11, 1) Validation: (1184, 11, 1) Test: (1185, 11, 1)

# %%
x_train = train_data[:, :-1, :]
y_train = train_data[:, -1, -1]  # Target (samples,)

x_valid = val_data[:, :-1, :]
y_valid = val_data[:, -1, -1]

x_test = test_data[:, :-1, :]
y_test = test_data[:, -1, -1]

# Kiểm tra kích thước của các tập dữ liệu
print(f"x_train shape: {x_train.shape}")  # (samples, timesteps * features)
print(f"y_train shape: {y_train.shape}")  # (samples,)
print(f"x_valid shape: {x_valid.shape}")
print(f"y_valid shape: {y_valid.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (3552, 10, 1)
# y_train shape: (3552,)
# x_valid shape: (1184, 10, 1)
# y_valid shape: (1184,)
# x_test shape: (1185, 10, 1)
# y_test shape: (1185,)

# %%
seq_len2 = 11
sequence2 = []
for index in range(len(r_t) - seq_len + 1):
    sequence2.append(r_t[index: index + seq_len])
sequence2 = np.array(sequence2)
train_data2, val_data2, test_data2 = split_data(sequence2)
x_test2 = test_data[:, :-1, :].reshape(test_data.shape[0], -1)  # Flatten test set
y_test2 = test_data[:, -1, -1]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K

# %%
import math
pi=math.pi
pi
# Out:
# 3.141592653589793

# %%
def mse_loss(y_true, y_pred):
    # Giả sử y_pred chứa cả giá trị dự đoán (r_t) và độ biến động (sigma_t)
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = tf.cast(y_pred, dtype=tf.float32) # Độ biến động dự đoán (sigma_t)
    l = tf.cast(tf.shape(r_t)[0], dtype=tf.float32)

    # Tính log-likelihood loss
    loss = (K.sum((r_t-sigma_t)**2))/l
    return loss
def log_likelihood_function(y_true, y_pred):
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = tf.cast(y_pred, dtype=tf.float32) # Cast y_pred to tf.float32 as well
    # Constants
    import math
    pi=math.pi

    # Calculate log-likelihood using TensorFlow operations
    log_likelihood = K.sum(-0.5*K.log(2*pi) - 2 * K.log(sigma_t) - K.square(r_t) / K.square(sigma_t))

    return log_likelihood

def build_lstm_model(input_length, lstm_units, fc_units, dropout_rate,optimizer):
    model = Sequential()

    # LSTM layer - Set return_sequences=True to output hidden states for all timesteps
    model.add(LSTM(units=lstm_units, input_shape=(input_length, 1), return_sequences=True))

    # Fully connected layer (Dense) - Now receives 3D input from previous LSTM
    model.add(LSTM(fc_units, activation='relu', return_sequences=True)) # Added return_sequences=True here
    model.add(Dropout(dropout_rate))

    # Output layer - output sigma_t (độ biến động dự đoán)
    model.add(LSTM(1, activation='sigmoid'))

    # Biên dịch mô hình với hàm mất mát log-likelihood
    model.compile(optimizer=optimizer, loss=mse_loss)

    return model

# %%
import tensorflow as tf
input_length = 10  # Độ dài chuỗi đầu vào
dnn_units = 20    # Số lượng units trong lớp LSTM
fc_units = 40     # Số lượng units trong lớp fully connected
dropout_rate = 0.3 # Tỷ lệ dropout
batch_size = 32  # Kích thước batch
epochs = 500        # Số epoch cho quá trình huấn luyện
optimizer = RMSprop()
# Xây dựng mô hình
model = build_lstm_model(input_length, dnn_units, fc_units, dropout_rate,optimizer)

# Huấn luyện mô hình với dữ liệu generator
history = model.fit(
    x_train,
    y_train,                    # Dữ liệu huấn luyện
    steps_per_epoch=100, # Số bước mỗi epoch
    epochs=epochs,                # Số epoch
    validation_data=(x_valid,y_valid),      # Dữ liệu xác thực
    batch_size=batch_size,
    shuffle= False  # Kích thước batch
    )
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0770 - val_loss: 3.0000e-05
# Epoch 2/500
#  10/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.9281e-05
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2996e-05 - val_loss: 4.2038e-05
# Epoch 3/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.7523e-04 - val_loss: 6.2746e-05
# Epoch 4/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0210e-05 - val_loss: 6.5533e-05
# Epoch 5/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3036e-04 - val_loss: 4.9197e-05
# Epoch 6/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5310e-05 - val_loss: 5.4158e-05
# Epoch 7/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.2199e-04 - val_loss: 4.4498e-05
# Epoch 8/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1136e-05 - val_loss: 5.3926e-05
# Epoch 9/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3729e-04 - val_loss: 4.1746e-05
# Epoch 10/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6286e-05 - val_loss: 4.4448e-05
# Epoch 11/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1427e-04 - val_loss: 4.5972e-05
# Epoch 12/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0458e-05 - val_loss: 4.9498e-05
# Epoch 13/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2058e-04 - val_loss: 3.6686e-05
# Epoch 14/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1879e-05 - val_loss: 4.6833e-05
# Epoch 15/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0620e-04 - val_loss: 3.9143e-05
# Epoch 16/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1689e-05 - val_loss: 4.5426e-05
# Epoch 17/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0343e-04 - val_loss: 3.8539e-05
# Epoch 18/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1768e-05 - val_loss: 3.8217e-05
# Epoch 19/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0125e-04 - val_loss: 3.8992e-05
# Epoch 20/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3684e-05 - val_loss: 3.9010e-05
# Epoch 21/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8641e-04 - val_loss: 3.4098e-05
# Epoch 22/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7225e-05 - val_loss: 3.8930e-05
# Epoch 23/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8610e-04 - val_loss: 3.5263e-05
# Epoch 24/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5760e-05 - val_loss: 3.9460e-05
# Epoch 25/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.8276e-04 - val_loss: 3.4760e-05
# Epoch 26/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0709e-05 - val_loss: 3.2434e-05
# Epoch 27/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.9651e-04 - val_loss: 3.2883e-05
# Epoch 28/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0816e-05 - val_loss: 3.5967e-05
# Epoch 29/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8675e-04 - val_loss: 3.5860e-05
# Epoch 30/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3104e-05 - val_loss: 4.2129e-05
# Epoch 31/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9089e-04 - val_loss: 3.2925e-05
# Epoch 32/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7006e-05 - val_loss: 3.7822e-05
# Epoch 33/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8544e-04 - val_loss: 3.3132e-05
# Epoch 34/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9485e-05 - val_loss: 3.1255e-05
# Epoch 35/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7913e-04 - val_loss: 3.2864e-05
# Epoch 36/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1578e-05 - val_loss: 3.2135e-05
# Epoch 37/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9230e-04 - val_loss: 3.0391e-05
# Epoch 38/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4163e-05 - val_loss: 3.2305e-05
# Epoch 39/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8286e-04 - val_loss: 3.0462e-05
# Epoch 40/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1354e-05 - val_loss: 3.0381e-05
# Epoch 41/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9423e-04 - val_loss: 3.4964e-05
# Epoch 42/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8213e-05 - val_loss: 3.4428e-05
# Epoch 43/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.9183e-04 - val_loss: 2.8992e-05
# Epoch 44/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2122e-05 - val_loss: 3.5623e-05
# Epoch 45/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.8873e-04 - val_loss: 3.3069e-05
# Epoch 46/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8092e-05 - val_loss: 3.2454e-05
# Epoch 47/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7400e-04 - val_loss: 2.7828e-05
# Epoch 48/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5535e-05 - val_loss: 2.5818e-05
# Epoch 49/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.8369e-04 - val_loss: 2.6488e-05
# Epoch 50/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7884e-05 - val_loss: 2.4982e-05
# Epoch 51/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7407e-04 - val_loss: 3.3615e-05
# Epoch 52/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5975e-05 - val_loss: 3.4731e-05
# Epoch 53/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6955e-04 - val_loss: 2.7696e-05
# Epoch 54/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3623e-05 - val_loss: 3.1156e-05
# Epoch 55/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8466e-04 - val_loss: 2.9554e-05
# Epoch 56/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4712e-05 - val_loss: 3.0896e-05
# Epoch 57/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7204e-04 - val_loss: 2.9354e-05
# Epoch 58/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6231e-05 - val_loss: 2.7338e-05
# Epoch 59/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8745e-04 - val_loss: 2.6452e-05
# Epoch 60/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8364e-05 - val_loss: 2.8571e-05
# Epoch 61/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7825e-04 - val_loss: 3.3340e-05
# Epoch 62/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1605e-05 - val_loss: 3.1226e-05
# Epoch 63/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.7245e-04 - val_loss: 2.5819e-05
# Epoch 64/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9474e-05 - val_loss: 2.5235e-05
# Epoch 65/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7149e-04 - val_loss: 2.4988e-05
# Epoch 66/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8113e-05 - val_loss: 2.5617e-05
# Epoch 67/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8367e-04 - val_loss: 2.6048e-05
# Epoch 68/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4745e-05 - val_loss: 3.1158e-05
# Epoch 69/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7735e-04 - val_loss: 2.2938e-05
# Epoch 70/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5816e-05 - val_loss: 2.7013e-05
# Epoch 71/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7318e-04 - val_loss: 2.8011e-05
# Epoch 72/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5039e-05 - val_loss: 2.6659e-05
# Epoch 73/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7031e-04 - val_loss: 2.5189e-05
# Epoch 74/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8658e-05 - val_loss: 2.9464e-05
# Epoch 75/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8799e-04 - val_loss: 2.5828e-05
# Epoch 76/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4146e-05 - val_loss: 3.0109e-05
# Epoch 77/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6271e-04 - val_loss: 2.5557e-05
# Epoch 78/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0108e-05 - val_loss: 2.6752e-05
# Epoch 79/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7089e-04 - val_loss: 2.2261e-05
# Epoch 80/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2475e-05 - val_loss: 2.2808e-05
# Epoch 81/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6883e-04 - val_loss: 2.5654e-05
# Epoch 82/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9766e-05 - val_loss: 2.6873e-05
# Epoch 83/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7492e-04 - val_loss: 2.2852e-05
# Epoch 84/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1532e-05 - val_loss: 2.3551e-05
# Epoch 85/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.6825e-04 - val_loss: 2.2702e-05
# Epoch 86/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9349e-05 - val_loss: 2.8531e-05
# Epoch 87/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7812e-04 - val_loss: 2.1762e-05
# Epoch 88/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8358e-05 - val_loss: 2.3527e-05
# Epoch 89/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6574e-04 - val_loss: 2.3894e-05
# Epoch 90/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0797e-05 - val_loss: 2.6088e-05
# Epoch 91/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6644e-04 - val_loss: 2.2579e-05
# Epoch 92/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9615e-05 - val_loss: 2.2444e-05
# Epoch 93/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6899e-04 - val_loss: 2.1810e-05
# Epoch 94/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1847e-05 - val_loss: 2.5009e-05
# Epoch 95/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6501e-04 - val_loss: 2.1256e-05
# Epoch 96/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6121e-05 - val_loss: 2.2919e-05
# Epoch 97/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6471e-04 - val_loss: 2.0633e-05
# Epoch 98/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3654e-05 - val_loss: 2.2355e-05
# Epoch 99/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5606e-04 - val_loss: 2.0667e-05
# Epoch 100/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0762e-05 - val_loss: 2.2295e-05
# Epoch 101/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6352e-04 - val_loss: 2.2588e-05
# Epoch 102/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3161e-05 - val_loss: 2.2415e-05
# Epoch 103/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6277e-04 - val_loss: 2.2125e-05
# Epoch 104/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6138e-05 - val_loss: 2.2857e-05
# Epoch 105/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6212e-04 - val_loss: 2.1459e-05
# Epoch 106/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7489e-05 - val_loss: 2.3934e-05
# Epoch 107/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.5680e-04 - val_loss: 2.0924e-05
# Epoch 108/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1111e-05 - val_loss: 2.1847e-05
# Epoch 109/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5880e-04 - val_loss: 1.9753e-05
# Epoch 110/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0160e-05 - val_loss: 2.1550e-05
# Epoch 111/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6665e-04 - val_loss: 2.1004e-05
# Epoch 112/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7745e-05 - val_loss: 2.3247e-05
# Epoch 113/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6064e-04 - val_loss: 2.0995e-05
# Epoch 114/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5932e-05 - val_loss: 2.3952e-05
# Epoch 115/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7123e-04 - val_loss: 2.0896e-05
# Epoch 116/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0690e-05 - val_loss: 2.5806e-05
# Epoch 117/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5889e-04 - val_loss: 2.0611e-05
# Epoch 118/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0193e-05 - val_loss: 2.1482e-05
# Epoch 119/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5728e-04 - val_loss: 2.1023e-05
# Epoch 120/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2491e-05 - val_loss: 2.3063e-05
# Epoch 121/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5954e-04 - val_loss: 2.0355e-05
# Epoch 122/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3101e-05 - val_loss: 2.3483e-05
# Epoch 123/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5738e-04 - val_loss: 1.9584e-05
# Epoch 124/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6152e-05 - val_loss: 2.1518e-05
# Epoch 125/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.5388e-04 - val_loss: 1.9745e-05
# Epoch 126/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2921e-05 - val_loss: 2.1482e-05
# Epoch 127/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5793e-04 - val_loss: 1.9270e-05
# Epoch 128/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0753e-05 - val_loss: 2.2934e-05
# Epoch 129/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6279e-04 - val_loss: 1.8463e-05
# Epoch 130/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6342e-05 - val_loss: 2.0895e-05
# Epoch 131/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5548e-04 - val_loss: 1.8980e-05
# Epoch 132/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8236e-05 - val_loss: 2.2175e-05
# Epoch 133/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5541e-04 - val_loss: 1.8843e-05
# Epoch 134/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2352e-05 - val_loss: 2.0949e-05
# Epoch 135/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5292e-04 - val_loss: 1.9051e-05
# Epoch 136/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4826e-05 - val_loss: 1.9534e-05
# Epoch 137/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5232e-04 - val_loss: 1.9079e-05
# Epoch 138/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5842e-05 - val_loss: 1.9219e-05
# Epoch 139/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5236e-04 - val_loss: 1.9364e-05
# Epoch 140/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6789e-05 - val_loss: 1.9031e-05
# Epoch 141/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5625e-04 - val_loss: 1.9021e-05
# Epoch 142/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1603e-05 - val_loss: 1.9783e-05
# Epoch 143/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5478e-04 - val_loss: 1.8007e-05
# Epoch 144/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6911e-05 - val_loss: 2.1093e-05
# Epoch 145/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5673e-04 - val_loss: 1.7711e-05
# Epoch 146/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7835e-05 - val_loss: 2.0266e-05
# Epoch 147/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6215e-04 - val_loss: 1.7683e-05
# Epoch 148/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2344e-05 - val_loss: 1.9572e-05
# Epoch 149/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.5032e-04 - val_loss: 1.8911e-05
# Epoch 150/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0603e-05 - val_loss: 1.9625e-05
# Epoch 151/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5377e-04 - val_loss: 1.7818e-05
# Epoch 152/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0414e-05 - val_loss: 1.9334e-05
# Epoch 153/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5129e-04 - val_loss: 1.7606e-05
# Epoch 154/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8622e-05 - val_loss: 2.0028e-05
# Epoch 155/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4865e-04 - val_loss: 1.8677e-05
# Epoch 156/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7777e-05 - val_loss: 2.0972e-05
# Epoch 157/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5710e-04 - val_loss: 1.8286e-05
# Epoch 158/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1973e-05 - val_loss: 1.7709e-05
# Epoch 159/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5094e-04 - val_loss: 1.7450e-05
# Epoch 160/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9869e-05 - val_loss: 1.9010e-05
# Epoch 161/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5448e-04 - val_loss: 1.7256e-05
# Epoch 162/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6705e-05 - val_loss: 1.8623e-05
# Epoch 163/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4743e-04 - val_loss: 1.8059e-05
# Epoch 164/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1188e-05 - val_loss: 1.9391e-05
# Epoch 165/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5599e-04 - val_loss: 1.8234e-05
# Epoch 166/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7762e-05 - val_loss: 2.0299e-05
# Epoch 167/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4952e-04 - val_loss: 1.7405e-05
# Epoch 168/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8225e-05 - val_loss: 1.8938e-05
# Epoch 169/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4656e-04 - val_loss: 1.7174e-05
# Epoch 170/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6361e-05 - val_loss: 1.8887e-05
# Epoch 171/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.5942e-04 - val_loss: 1.7101e-05
# Epoch 172/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7852e-05 - val_loss: 1.8019e-05
# Epoch 173/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4203e-04 - val_loss: 1.7218e-05
# Epoch 174/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7652e-05 - val_loss: 1.8372e-05
# Epoch 175/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4548e-04 - val_loss: 1.7086e-05
# Epoch 176/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3807e-05 - val_loss: 1.7764e-05
# Epoch 177/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5170e-04 - val_loss: 1.7720e-05
# Epoch 178/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1149e-05 - val_loss: 1.8523e-05
# Epoch 179/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5148e-04 - val_loss: 1.7526e-05
# Epoch 180/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9774e-05 - val_loss: 1.8855e-05
# Epoch 181/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5265e-04 - val_loss: 1.7386e-05
# Epoch 182/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7475e-05 - val_loss: 1.8415e-05
# Epoch 183/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5115e-04 - val_loss: 1.7314e-05
# Epoch 184/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4710e-05 - val_loss: 1.9070e-05
# Epoch 185/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5078e-04 - val_loss: 1.7045e-05
# Epoch 186/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6909e-05 - val_loss: 1.8168e-05
# Epoch 187/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.5270e-04 - val_loss: 1.7079e-05
# Epoch 188/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7708e-05 - val_loss: 1.7897e-05
# Epoch 189/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5262e-04 - val_loss: 1.6954e-05
# Epoch 190/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8430e-05 - val_loss: 1.8237e-05
# Epoch 191/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.5146e-04 - val_loss: 1.6914e-05
# Epoch 192/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4405e-05 - val_loss: 1.7144e-05
# Epoch 193/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4997e-04 - val_loss: 1.6912e-05
# Epoch 194/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4662e-05 - val_loss: 1.8264e-05
# Epoch 195/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4821e-04 - val_loss: 1.7273e-05
# Epoch 196/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3203e-05 - val_loss: 1.8917e-05
# Epoch 197/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4937e-04 - val_loss: 1.7018e-05
# Epoch 198/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3175e-05 - val_loss: 1.7509e-05
# Epoch 199/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4888e-04 - val_loss: 1.7002e-05
# Epoch 200/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1704e-05 - val_loss: 1.7259e-05
# Epoch 201/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4624e-04 - val_loss: 1.6960e-05
# Epoch 202/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1203e-05 - val_loss: 1.7667e-05
# Epoch 203/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4992e-04 - val_loss: 1.6934e-05
# Epoch 204/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9360e-05 - val_loss: 1.7901e-05
# Epoch 205/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.4938e-04 - val_loss: 1.6907e-05
# Epoch 206/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3779e-05 - val_loss: 1.7237e-05
# Epoch 207/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4862e-04 - val_loss: 1.7025e-05
# Epoch 208/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2392e-05 - val_loss: 1.7207e-05
# Epoch 209/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.4490e-04 - val_loss: 1.6926e-05
# Epoch 210/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5680e-05 - val_loss: 1.7529e-05
# Epoch 211/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4674e-04 - val_loss: 1.6926e-05
# Epoch 212/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4520e-05 - val_loss: 1.7625e-05
# Epoch 213/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4191e-04 - val_loss: 1.7042e-05
# Epoch 214/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7768e-05 - val_loss: 1.7160e-05
# Epoch 215/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4149e-04 - val_loss: 1.7403e-05
# Epoch 216/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7012e-05 - val_loss: 1.6956e-05
# Epoch 217/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4291e-04 - val_loss: 1.6906e-05
# Epoch 218/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5805e-05 - val_loss: 1.7400e-05
# Epoch 219/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4445e-04 - val_loss: 1.7014e-05
# Epoch 220/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7916e-05 - val_loss: 1.7094e-05
# Epoch 221/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4704e-04 - val_loss: 1.6917e-05
# Epoch 222/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0269e-05 - val_loss: 1.7233e-05
# Epoch 223/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4810e-04 - val_loss: 1.6900e-05
# Epoch 224/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6267e-05 - val_loss: 1.7277e-05
# Epoch 225/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4099e-04 - val_loss: 1.7001e-05
# Epoch 226/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3409e-05 - val_loss: 1.7169e-05
# Epoch 227/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.4669e-04 - val_loss: 1.6988e-05
# Epoch 228/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0586e-05 - val_loss: 1.7086e-05
# Epoch 229/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4514e-04 - val_loss: 1.7219e-05
# Epoch 230/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9280e-05 - val_loss: 1.7009e-05
# Epoch 231/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4297e-04 - val_loss: 1.7162e-05
# Epoch 232/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6941e-05 - val_loss: 1.6939e-05
# Epoch 233/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3812e-04 - val_loss: 1.7346e-05
# Epoch 234/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1999e-05 - val_loss: 1.6897e-05
# Epoch 235/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4668e-04 - val_loss: 1.7114e-05
# Epoch 236/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7731e-05 - val_loss: 1.7040e-05
# Epoch 237/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4329e-04 - val_loss: 1.7433e-05
# Epoch 238/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0515e-05 - val_loss: 1.6946e-05
# Epoch 239/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4893e-04 - val_loss: 1.7088e-05
# Epoch 240/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4514e-05 - val_loss: 1.6924e-05
# Epoch 241/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4141e-04 - val_loss: 1.7358e-05
# Epoch 242/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4929e-05 - val_loss: 1.7005e-05
# Epoch 243/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3530e-04 - val_loss: 1.8121e-05
# Epoch 244/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8231e-05 - val_loss: 1.6926e-05
# Epoch 245/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.3612e-04 - val_loss: 1.7627e-05
# Epoch 246/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8741e-05 - val_loss: 1.6918e-05
# Epoch 247/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.3984e-04 - val_loss: 1.7429e-05
# Epoch 248/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7951e-05 - val_loss: 1.6901e-05
# Epoch 249/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4138e-04 - val_loss: 1.7312e-05
# Epoch 250/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7425e-05 - val_loss: 1.6954e-05
# Epoch 251/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4102e-04 - val_loss: 1.8222e-05
# Epoch 252/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2565e-05 - val_loss: 1.7005e-05
# Epoch 253/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3736e-04 - val_loss: 1.8000e-05
# Epoch 254/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5130e-05 - val_loss: 1.6988e-05
# Epoch 255/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4025e-04 - val_loss: 1.8009e-05
# Epoch 256/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6156e-05 - val_loss: 1.6927e-05
# Epoch 257/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4216e-04 - val_loss: 1.7688e-05
# Epoch 258/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2941e-05 - val_loss: 1.6977e-05
# Epoch 259/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3712e-04 - val_loss: 1.7739e-05
# Epoch 260/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4428e-05 - val_loss: 1.6895e-05
# Epoch 261/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3548e-04 - val_loss: 1.7645e-05
# Epoch 262/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5844e-05 - val_loss: 1.6895e-05
# Epoch 263/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3846e-04 - val_loss: 1.8174e-05
# Epoch 264/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0135e-05 - val_loss: 1.6983e-05
# Epoch 265/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3652e-04 - val_loss: 1.7743e-05
# Epoch 266/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0364e-05 - val_loss: 1.7016e-05
# Epoch 267/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3129e-04 - val_loss: 1.8477e-05
# Epoch 268/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0906e-05 - val_loss: 1.7040e-05
# Epoch 269/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.4197e-04 - val_loss: 1.8384e-05
# Epoch 270/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3296e-05 - val_loss: 1.7032e-05
# Epoch 271/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4027e-04 - val_loss: 1.8245e-05
# Epoch 272/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2491e-05 - val_loss: 1.7016e-05
# Epoch 273/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3458e-04 - val_loss: 1.7938e-05
# Epoch 274/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0767e-05 - val_loss: 1.6916e-05
# Epoch 275/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3966e-04 - val_loss: 1.7942e-05
# Epoch 276/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5359e-05 - val_loss: 1.6934e-05
# Epoch 277/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3655e-04 - val_loss: 1.8032e-05
# Epoch 278/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5844e-05 - val_loss: 1.6997e-05
# Epoch 279/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3579e-04 - val_loss: 1.8587e-05
# Epoch 280/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3208e-05 - val_loss: 1.7061e-05
# Epoch 281/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3539e-04 - val_loss: 1.8405e-05
# Epoch 282/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8395e-05 - val_loss: 1.7248e-05
# Epoch 283/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3124e-04 - val_loss: 1.8854e-05
# Epoch 284/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8752e-05 - val_loss: 1.6990e-05
# Epoch 285/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4034e-04 - val_loss: 1.9369e-05
# Epoch 286/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6985e-05 - val_loss: 1.7271e-05
# Epoch 287/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.3287e-04 - val_loss: 1.8689e-05
# Epoch 288/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9579e-05 - val_loss: 1.7049e-05
# Epoch 289/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3343e-04 - val_loss: 1.9323e-05
# Epoch 290/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7518e-05 - val_loss: 1.7072e-05
# Epoch 291/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3713e-04 - val_loss: 1.8627e-05
# Epoch 292/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5058e-05 - val_loss: 1.7291e-05
# Epoch 293/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3188e-04 - val_loss: 1.8891e-05
# Epoch 294/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6993e-05 - val_loss: 1.7222e-05
# Epoch 295/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3497e-04 - val_loss: 1.9878e-05
# Epoch 296/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1021e-05 - val_loss: 1.7876e-05
# Epoch 297/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3411e-04 - val_loss: 1.8278e-05
# Epoch 298/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9960e-05 - val_loss: 1.7231e-05
# Epoch 299/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3186e-04 - val_loss: 1.9518e-05
# Epoch 300/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7688e-05 - val_loss: 1.7419e-05
# Epoch 301/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3713e-04 - val_loss: 2.0664e-05
# Epoch 302/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8075e-05 - val_loss: 1.7612e-05
# Epoch 303/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3709e-04 - val_loss: 1.9871e-05
# Epoch 304/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6894e-05 - val_loss: 1.7407e-05
# Epoch 305/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.3273e-04 - val_loss: 1.9692e-05
# Epoch 306/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6042e-05 - val_loss: 1.7390e-05
# Epoch 307/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3229e-04 - val_loss: 1.9668e-05
# Epoch 308/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8701e-05 - val_loss: 1.7657e-05
# Epoch 309/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.3068e-04 - val_loss: 1.9446e-05
# Epoch 310/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7189e-05 - val_loss: 1.7240e-05
# Epoch 311/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3485e-04 - val_loss: 2.0094e-05
# Epoch 312/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8381e-05 - val_loss: 1.7472e-05
# Epoch 313/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3458e-04 - val_loss: 1.9156e-05
# Epoch 314/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1603e-05 - val_loss: 1.7357e-05
# Epoch 315/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3319e-04 - val_loss: 1.9938e-05
# Epoch 316/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2526e-05 - val_loss: 1.7655e-05
# Epoch 317/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3134e-04 - val_loss: 1.9772e-05
# Epoch 318/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3975e-05 - val_loss: 1.7463e-05
# Epoch 319/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2995e-04 - val_loss: 2.0349e-05
# Epoch 320/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2949e-05 - val_loss: 1.7773e-05
# Epoch 321/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3167e-04 - val_loss: 2.0510e-05
# Epoch 322/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3732e-05 - val_loss: 1.8002e-05
# Epoch 323/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2769e-04 - val_loss: 2.0126e-05
# Epoch 324/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6918e-05 - val_loss: 1.7886e-05
# Epoch 325/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2942e-04 - val_loss: 2.1072e-05
# Epoch 326/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2971e-05 - val_loss: 1.8090e-05
# Epoch 327/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.3640e-04 - val_loss: 2.0382e-05
# Epoch 328/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6007e-05 - val_loss: 1.7714e-05
# Epoch 329/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3250e-04 - val_loss: 2.1139e-05
# Epoch 330/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1178e-05 - val_loss: 1.8004e-05
# Epoch 331/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3329e-04 - val_loss: 2.0840e-05
# Epoch 332/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9401e-05 - val_loss: 1.8593e-05
# Epoch 333/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3218e-04 - val_loss: 2.1646e-05
# Epoch 334/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7258e-05 - val_loss: 1.8122e-05
# Epoch 335/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3056e-04 - val_loss: 2.1935e-05
# Epoch 336/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6706e-05 - val_loss: 1.8479e-05
# Epoch 337/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3151e-04 - val_loss: 2.0044e-05
# Epoch 338/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3320e-05 - val_loss: 1.8156e-05
# Epoch 339/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2865e-04 - val_loss: 2.0515e-05
# Epoch 340/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0756e-05 - val_loss: 1.7991e-05
# Epoch 341/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3161e-04 - val_loss: 2.1599e-05
# Epoch 342/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2335e-05 - val_loss: 1.8777e-05
# Epoch 343/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2182e-04 - val_loss: 2.0982e-05
# Epoch 344/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4206e-05 - val_loss: 1.8089e-05
# Epoch 345/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3215e-04 - val_loss: 2.1087e-05
# Epoch 346/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1720e-05 - val_loss: 1.8398e-05
# Epoch 347/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3298e-04 - val_loss: 2.1336e-05
# Epoch 348/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7586e-05 - val_loss: 1.8692e-05
# Epoch 349/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2652e-04 - val_loss: 2.0860e-05
# Epoch 350/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1663e-05 - val_loss: 1.8232e-05
# Epoch 351/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2996e-04 - val_loss: 2.1926e-05
# Epoch 352/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7468e-05 - val_loss: 1.9327e-05
# Epoch 353/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2791e-04 - val_loss: 2.2303e-05
# Epoch 354/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8605e-05 - val_loss: 1.8613e-05
# Epoch 355/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2814e-04 - val_loss: 2.1548e-05
# Epoch 356/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2131e-05 - val_loss: 1.8880e-05
# Epoch 357/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3012e-04 - val_loss: 2.1232e-05
# Epoch 358/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1786e-05 - val_loss: 1.8620e-05
# Epoch 359/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2587e-04 - val_loss: 2.0800e-05
# Epoch 360/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3429e-05 - val_loss: 1.8259e-05
# Epoch 361/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2789e-04 - val_loss: 2.2988e-05
# Epoch 362/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4009e-05 - val_loss: 1.9381e-05
# Epoch 363/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2679e-04 - val_loss: 2.2017e-05
# Epoch 364/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6179e-05 - val_loss: 1.8619e-05
# Epoch 365/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.3345e-04 - val_loss: 2.2174e-05
# Epoch 366/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5338e-05 - val_loss: 1.9335e-05
# Epoch 367/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2780e-04 - val_loss: 2.0902e-05
# Epoch 368/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1544e-05 - val_loss: 1.8582e-05
# Epoch 369/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2832e-04 - val_loss: 2.2780e-05
# Epoch 370/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8511e-05 - val_loss: 1.9564e-05
# Epoch 371/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2527e-04 - val_loss: 2.2061e-05
# Epoch 372/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0329e-05 - val_loss: 1.8450e-05
# Epoch 373/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2664e-04 - val_loss: 2.2593e-05
# Epoch 374/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4549e-05 - val_loss: 1.9166e-05
# Epoch 375/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2411e-04 - val_loss: 2.2440e-05
# Epoch 376/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3210e-05 - val_loss: 1.9181e-05
# Epoch 377/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3092e-04 - val_loss: 2.2565e-05
# Epoch 378/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8440e-05 - val_loss: 1.9129e-05
# Epoch 379/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2350e-04 - val_loss: 2.2865e-05
# Epoch 380/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3485e-05 - val_loss: 1.9492e-05
# Epoch 381/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2881e-04 - val_loss: 2.2362e-05
# Epoch 382/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4138e-05 - val_loss: 1.9114e-05
# Epoch 383/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2887e-04 - val_loss: 2.2817e-05
# Epoch 384/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9433e-05 - val_loss: 1.9470e-05
# Epoch 385/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.2785e-04 - val_loss: 2.1895e-05
# Epoch 386/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3487e-05 - val_loss: 1.8826e-05
# Epoch 387/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2571e-04 - val_loss: 2.3391e-05
# Epoch 388/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0071e-05 - val_loss: 1.9875e-05
# Epoch 389/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2638e-04 - val_loss: 2.3125e-05
# Epoch 390/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1431e-05 - val_loss: 1.9772e-05
# Epoch 391/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2135e-04 - val_loss: 2.3886e-05
# Epoch 392/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0685e-05 - val_loss: 2.0113e-05
# Epoch 393/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2662e-04 - val_loss: 2.2750e-05
# Epoch 394/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4594e-05 - val_loss: 1.9553e-05
# Epoch 395/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2796e-04 - val_loss: 2.2988e-05
# Epoch 396/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9185e-05 - val_loss: 1.9796e-05
# Epoch 397/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2585e-04 - val_loss: 2.3680e-05
# Epoch 398/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3136e-05 - val_loss: 2.0059e-05
# Epoch 399/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2548e-04 - val_loss: 2.3969e-05
# Epoch 400/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3547e-05 - val_loss: 2.0066e-05
# Epoch 401/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2373e-04 - val_loss: 2.4514e-05
# Epoch 402/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9726e-05 - val_loss: 2.0855e-05
# Epoch 403/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2683e-04 - val_loss: 2.5187e-05
# Epoch 404/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8504e-05 - val_loss: 2.0132e-05
# Epoch 405/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.3129e-04 - val_loss: 2.4591e-05
# Epoch 406/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9217e-05 - val_loss: 2.0005e-05
# Epoch 407/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2208e-04 - val_loss: 2.3958e-05
# Epoch 408/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2506e-05 - val_loss: 2.0463e-05
# Epoch 409/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2412e-04 - val_loss: 2.3233e-05
# Epoch 410/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0209e-05 - val_loss: 2.0235e-05
# Epoch 411/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2347e-04 - val_loss: 2.4250e-05
# Epoch 412/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1700e-05 - val_loss: 2.0422e-05
# Epoch 413/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2343e-04 - val_loss: 2.4204e-05
# Epoch 414/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2657e-05 - val_loss: 2.0182e-05
# Epoch 415/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2597e-04 - val_loss: 2.4255e-05
# Epoch 416/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9190e-05 - val_loss: 2.0927e-05
# Epoch 417/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2322e-04 - val_loss: 2.4899e-05
# Epoch 418/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2611e-05 - val_loss: 2.0387e-05
# Epoch 419/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2749e-04 - val_loss: 2.4711e-05
# Epoch 420/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6969e-05 - val_loss: 2.1199e-05
# Epoch 421/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2349e-04 - val_loss: 2.4277e-05
# Epoch 422/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2945e-05 - val_loss: 2.0459e-05
# Epoch 423/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2124e-04 - val_loss: 2.5283e-05
# Epoch 424/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2509e-05 - val_loss: 2.1110e-05
# Epoch 425/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2337e-04 - val_loss: 2.4553e-05
# Epoch 426/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1770e-05 - val_loss: 2.0986e-05
# Epoch 427/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2705e-04 - val_loss: 2.4557e-05
# Epoch 428/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1342e-05 - val_loss: 2.0741e-05
# Epoch 429/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2451e-04 - val_loss: 2.4381e-05
# Epoch 430/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1176e-05 - val_loss: 2.1201e-05
# Epoch 431/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2560e-04 - val_loss: 2.5467e-05
# Epoch 432/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7802e-05 - val_loss: 2.1459e-05
# Epoch 433/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1997e-04 - val_loss: 2.4846e-05
# Epoch 434/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9044e-05 - val_loss: 2.0772e-05
# Epoch 435/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2358e-04 - val_loss: 2.4544e-05
# Epoch 436/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8858e-05 - val_loss: 2.1147e-05
# Epoch 437/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2486e-04 - val_loss: 2.5184e-05
# Epoch 438/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2485e-05 - val_loss: 2.1047e-05
# Epoch 439/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2424e-04 - val_loss: 2.5158e-05
# Epoch 440/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1206e-05 - val_loss: 2.1478e-05
# Epoch 441/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.2813e-04 - val_loss: 2.5536e-05
# Epoch 442/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0058e-05 - val_loss: 2.1276e-05
# Epoch 443/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2429e-04 - val_loss: 2.6023e-05
# Epoch 444/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9487e-05 - val_loss: 2.2302e-05
# Epoch 445/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1730e-04 - val_loss: 2.5863e-05
# Epoch 446/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2900e-05 - val_loss: 2.1306e-05
# Epoch 447/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2386e-04 - val_loss: 2.4602e-05
# Epoch 448/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9012e-05 - val_loss: 2.1133e-05
# Epoch 449/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2139e-04 - val_loss: 2.6220e-05
# Epoch 450/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7683e-05 - val_loss: 2.2432e-05
# Epoch 451/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2324e-04 - val_loss: 2.5761e-05
# Epoch 452/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2844e-05 - val_loss: 2.1556e-05
# Epoch 453/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2279e-04 - val_loss: 2.5580e-05
# Epoch 454/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0011e-05 - val_loss: 2.1587e-05
# Epoch 455/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2324e-04 - val_loss: 2.6062e-05
# Epoch 456/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7644e-05 - val_loss: 2.2176e-05
# Epoch 457/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2482e-04 - val_loss: 2.6098e-05
# Epoch 458/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8936e-05 - val_loss: 2.2205e-05
# Epoch 459/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2020e-04 - val_loss: 2.5938e-05
# Epoch 460/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8939e-05 - val_loss: 2.2194e-05
# Epoch 461/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2108e-04 - val_loss: 2.6153e-05
# Epoch 462/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6061e-05 - val_loss: 2.1491e-05
# Epoch 463/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2176e-04 - val_loss: 2.6177e-05
# Epoch 464/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7958e-05 - val_loss: 2.2333e-05
# Epoch 465/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2251e-04 - val_loss: 2.6511e-05
# Epoch 466/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7476e-05 - val_loss: 2.2318e-05
# Epoch 467/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1975e-04 - val_loss: 2.6365e-05
# Epoch 468/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0483e-05 - val_loss: 2.2434e-05
# Epoch 469/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2413e-04 - val_loss: 2.6392e-05
# Epoch 470/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0470e-05 - val_loss: 2.2263e-05
# Epoch 471/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2094e-04 - val_loss: 2.6301e-05
# Epoch 472/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7229e-05 - val_loss: 2.2608e-05
# Epoch 473/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2407e-04 - val_loss: 2.6597e-05
# Epoch 474/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8568e-05 - val_loss: 2.2620e-05
# Epoch 475/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1985e-04 - val_loss: 2.5937e-05
# Epoch 476/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8841e-05 - val_loss: 2.2142e-05
# Epoch 477/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1896e-04 - val_loss: 2.6464e-05
# Epoch 478/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7807e-05 - val_loss: 2.2448e-05
# Epoch 479/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2238e-04 - val_loss: 2.6580e-05
# Epoch 480/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1645e-05 - val_loss: 2.2085e-05
# Epoch 481/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2165e-04 - val_loss: 2.7336e-05
# Epoch 482/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9114e-05 - val_loss: 2.2560e-05
# Epoch 483/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2025e-04 - val_loss: 2.6670e-05
# Epoch 484/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2723e-05 - val_loss: 2.2528e-05
# Epoch 485/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1525e-04 - val_loss: 2.6980e-05
# Epoch 486/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1281e-05 - val_loss: 2.2654e-05
# Epoch 487/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2054e-04 - val_loss: 2.7481e-05
# Epoch 488/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1267e-05 - val_loss: 2.3169e-05
# Epoch 489/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2038e-04 - val_loss: 2.7348e-05
# Epoch 490/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1689e-05 - val_loss: 2.3077e-05
# Epoch 491/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1888e-04 - val_loss: 2.7577e-05
# Epoch 492/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8484e-05 - val_loss: 2.3267e-05
# Epoch 493/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2347e-04 - val_loss: 2.7546e-05
# Epoch 494/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7317e-05 - val_loss: 2.3269e-05
# Epoch 495/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.1783e-04 - val_loss: 2.7222e-05
# Epoch 496/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0346e-05 - val_loss: 2.2792e-05
# Epoch 497/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.2010e-04 - val_loss: 2.6994e-05
# Epoch 498/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0095e-05 - val_loss: 2.2770e-05
# Epoch 499/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2155e-04 - val_loss: 2.7446e-05
# Epoch 500/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0540e-05 - val_loss: 2.3266e-05

# %%
# prompt: đưa ra giá trị loss nhỏ nhất, ở epoch nào

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'history' is the training history object from model.fit
min_loss = np.min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['loss'])

print(f"Minimum loss: {min_loss} at epoch {min_loss_epoch}")
# Out:
# Minimum loss: 2.4694250896573067e-05 at epoch 365

# %%
# prompt: vẽ biểu đồ loss

import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# prompt: đưa ra giá trị dự đoán của mô hình cho test_gen

# Assuming 'model' and 'test_gen' are defined as in the previous code.
# Get predictions for the test data
predictions = model.predict(x_test)

# Print the predictions
predictions
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# array([[0.01175986],
#        [0.01177792],
#        [0.01178706],
#        ...,
#        [0.01139632],
#        [0.01139879],
#        [0.01140087]], dtype=float32)

# %%
predictions.shape
# Out:
# (1185, 1)

# %%
r_t = tf.cast(y_test2, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
sigma_t = tf.cast(predictions, dtype=tf.float32) # Cast y_pred to tf.float32 as well
# Constants
import math
pi=math.pi

# Calculate log-likelihood
# Use tf.math.log, tf.math.square, and tf.math.reduce_sum
log_L = np.sum(-0.5 * np.log(2 *pi) - np.log(sigma_t) - (r_t**2) / (2 * sigma_t**2))
log_L
# Out:
# 4104969.8

# %%
# prompt: vẽ biểu đồ chỉ có predictions

import matplotlib.pyplot as plt

# Assuming 'predictions' is already defined from your model.predict call
# and has the correct shape (number of test samples, 1)

plt.figure(figsize=(10, 6))
plt.plot(predictions, label='Predictions')
plt.title('Bitcoin Price Predictions')
plt.ylabel('Predicted Return')
plt.xlabel('Time Step')
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: xuất giá trị predictions ra excel và lưu vào drive

import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming 'predictions' is a NumPy array containing your model's predictions
# Create a Pandas DataFrame from the predictions
predictions_df = pd.DataFrame(predictions, columns=['Predicted Volatility'])

# Specify the output file path in your Google Drive
output_file_path = '/content/drive/MyDrive/predictionslstmmse.xlsx'

# Export the DataFrame to an Excel file
predictions_df.to_excel(output_file_path, index=False)

print(f"Predictions exported to: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Predictions exported to: /content/drive/MyDrive/predictionslstmmse.xlsx
