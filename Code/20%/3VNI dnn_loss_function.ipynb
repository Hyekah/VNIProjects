# %%
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
from tqdm.notebook import tqdm
from datetime import timedelta
import matplotlib.pyplot as plt
from IPython.display import Image
import plotly.graph_objects as go
from keras.utils import plot_model
from keras.models import Sequential
from IPython.display import Image, display
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from tensorflow.keras.layers import Embedding, SpatialDropout1D, Bidirectional, LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/1VNIndex.xlsx' # Đường dẫn đã được cập nhật
df = pd.read_excel(file_path)
# Out:
# Mounted at /content/drive

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#              Price
# Date
# 2000-07-31  101.55
# 2000-08-02  103.38
# 2000-08-04  105.20
# 2000-08-07  106.92
# 2000-08-09  108.64

# %%
return_series=np.log(df['Price']/df['Price'].shift(1))

# %%
return_series = return_series.dropna()

# %%
return_series
# Out:
# Date
# 2000-08-02    0.017860
# 2000-08-04    0.017452
# 2000-08-07    0.016218
# 2000-08-09    0.015959
# 2000-08-11    0.015708
#                 ...
# 2024-12-10   -0.001390
# 2024-12-11   -0.002527
# 2024-12-12   -0.001191
# 2024-12-13   -0.003779
# 2024-12-16    0.000966
# Name: Price, Length: 5931, dtype: float64

# %%
r_t=return_series.values.reshape(5931,1)

# %%
# prompt: đưa ra bảng mô tả thống kê, kurtosis, jacque cho r_t

import pandas as pd
import numpy as np

# Assuming 'return_series' and 'r_t' are defined as in the previous code
# ... (your existing code) ...

# Calculate descriptive statistics
r_t_series = pd.Series(r_t.flatten()) # Convert r_t to a pandas Series for easier calculations
description = r_t_series.describe()

# Calculate kurtosis and skewness (Fisher's definition)
kurtosis = r_t_series.kurtosis()
skewness = r_t_series.skew()


# Print the results
print("Descriptive Statistics:")
print(description)
print("\nKurtosis:", kurtosis)
print("\nSkewness (Fisher):", skewness)

# Create a summary table
summary_table = pd.DataFrame({
    'Statistic': ['Count', 'Mean', 'Standard Deviation', 'Min', '25%', '50%', '75%', 'Max', 'Kurtosis', 'Skewness'],
    'Value': [description['count'], description['mean'], description['std'], description['min'], description['25%'],
              description['50%'], description['75%'], description['max'], kurtosis, skewness]
})

print("\nSummary Table:")
summary_table
# Out:
# Descriptive Statistics:
# count    5931.000000
# mean        0.000425
# std         0.014439
# min        -0.076557
# 25%        -0.005534
# 50%         0.000607
# 75%         0.007378
# max         0.066561
# dtype: float64
#
# Kurtosis: 3.4097427278606807
#
# Skewness (Fisher): -0.3953987594767815
#
# Summary Table:
#             Statistic        Value
# 0               Count  5931.000000
# 1                Mean     0.000425
# 2  Standard Deviation     0.014439
# 3                 Min    -0.076557
# 4                 25%    -0.005534
# 5                 50%     0.000607
# 6                 75%     0.007378
# 7                 Max     0.066561
# 8            Kurtosis     3.409743
# 9            Skewness    -0.395399

# %%
# prompt: đưa ra kết quả jacque bera test cho r_t

import numpy as np
import pandas as pd
from scipy.stats import jarque_bera

# Assuming 'r_t' is defined as in the previous code
# ... (your existing code) ...

# Perform Jarque-Bera test
jb_statistic, p_value = jarque_bera(r_t.flatten())

print("\nJarque-Bera Test:")
print("Statistic:", jb_statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The data does not follow a normal distribution.")
else:
    print("Fail to reject the null hypothesis: The data may follow a normal distribution.")
# Out:
# Jarque-Bera Test:
# Statistic: 3021.0807048199413
# p-value: 0.0
# Reject the null hypothesis: The data does not follow a normal distribution.

# %%
from matplotlib import pyplot as plt
plt.plot(r_t)
plt.show()

# %%
plt.plot(r_t[:42])
plt.xticks(rotation=45)
plt.show()

# %%
seq_len = 11
sequence = []
for index in range(len(r_t) - seq_len + 1):
    sequence.append(r_t[index: index + seq_len])
sequence = np.array(sequence)
print(sequence.shape)
# Out:
# (5921, 11, 1)

# %%
def split_data(sequence):
    train_data, test_data = train_test_split(sequence, test_size=0.4, shuffle=False,random_state=42)
    val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=False,random_state=42)
    return train_data, val_data, test_data

# %%
train_data, val_data, test_data = split_data(sequence)
print("Train:", train_data.shape, "Validation:", val_data.shape, "Test:", test_data.shape)
# Out:
# Train: (3552, 11, 1) Validation: (1184, 11, 1) Test: (1185, 11, 1)

# %%
# Rải phẳng dữ liệu cho mô hình DNN
x_train = train_data[:, :-1, :].reshape(train_data.shape[0], -1)  # Flatten (samples, timesteps * features)
y_train = train_data[:, -1, -1]  # Target (samples,)

x_valid = val_data[:, :-1, :].reshape(val_data.shape[0], -1)  # Flatten validation set
y_valid = val_data[:, -1, -1]

x_test = test_data[:, :-1, :].reshape(test_data.shape[0], -1)  # Flatten test set
y_test = test_data[:, -1, -1]

# Kiểm tra kích thước của các tập dữ liệu
print(f"x_train shape: {x_train.shape}")  # (samples, timesteps * features)
print(f"y_train shape: {y_train.shape}")  # (samples,)
print(f"x_valid shape: {x_valid.shape}")
print(f"y_valid shape: {y_valid.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (3552, 10)
# y_train shape: (3552,)
# x_valid shape: (1184, 10)
# y_valid shape: (1184,)
# x_test shape: (1185, 10)
# y_test shape: (1185,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K

# %%
import math
pi=math.pi
pi
# Out:
# 3.141592653589793

# %%
def log_likelihood_loss(y_true, y_pred):
    # Giả sử y_pred chứa cả giá trị dự đoán (r_t) và độ biến động (sigma_t)
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = y_pred  # Độ biến động dự đoán (sigma_t)

    # Tính log-likelihood loss
    loss = K.sum(2 * K.log(sigma_t) + K.square(r_t) / K.square(sigma_t), axis=-1)
    return loss
def log_likelihood_function(y_true, y_pred):
    r_t = tf.cast(y_true, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
    sigma_t = tf.cast(y_pred, dtype=tf.float32) # Cast y_pred to tf.float32 as well
    # Constants
    import math
    pi=math.pi

    # Calculate log-likelihood using TensorFlow operations
    log_likelihood = K.sum(-0.5*K.log(2*pi) - 2 * K.log(sigma_t) - K.square(r_t) / K.square(sigma_t))

    return log_likelihood

def build_dnn_model(input_length, dnn_units, fc_units, dropout_rate, optimizer):
    model = Sequential()

    # Dense layer (instead of LSTM) - Changed input_shape to a tuple
    model.add(Dense(units=dnn_units))

    # Fully connected layer (Dense)
    model.add(Dense(fc_units, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Output layer - output sigma_t (độ biến động dự đoán)
    model.add(Dense(1, activation='sigmoid'))

    # Biên dịch mô hình với hàm mất mát log-likelihood
    model.compile(optimizer=optimizer, loss=log_likelihood_loss, metrics=[log_likelihood_function])

    return model

# %%
import tensorflow as tf
input_length = 10  # Độ dài chuỗi đầu vào
dnn_units = 20    # Số lượng units trong lớp LSTM
fc_units = 40      # Số lượng units trong lớp fully connected
dropout_rate = 0.3 # Tỷ lệ dropout
batch_size = 32  # Kích thước batch
epochs = 500        # Số epoch cho quá trình huấn luyện
optimizer = RMSprop()
# Xây dựng mô hình
model = build_dnn_model(input_length, dnn_units, fc_units, dropout_rate,optimizer)

# Huấn luyện mô hình với dữ liệu generator
history = model.fit(
    x_train,
    y_train,                    # Dữ liệu huấn luyện
    steps_per_epoch=100, # Số bước mỗi epoch
    epochs=epochs,                # Số epoch
    validation_data=(x_valid,y_valid),      # Dữ liệu xác thực
    batch_size=batch_size,
    shuffle= False  # Kích thước batch
    )

# Đánh giá mô hình trên tập kiểm tra (test)
test_loss, test_log_likelihood = model.evaluate(x_test, y_test)
print(f"Test loss (Log-Likelihood): {test_loss}")
print(f"Test log-likelihood: {test_log_likelihood}")
# Out:
# Epoch 1/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - log_likelihood_function: 1133.1880 - loss: -2.0256 - val_log_likelihood_function: 5849.8433 - val_loss: -6.6306
# Epoch 2/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5709.5073 - loss: -6.3947 - val_log_likelihood_function: 6749.2871 - val_loss: -7.5075
# Epoch 3/500
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - log_likelihood_function: 6393.6523 - loss: -7.2040
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - log_likelihood_function: 5666.4272 - loss: -6.5210 - val_log_likelihood_function: 7145.4028 - val_loss: -7.8931
# Epoch 4/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6041.0996 - loss: -6.7926 - val_log_likelihood_function: 7108.0205 - val_loss: -7.8581
# Epoch 5/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - log_likelihood_function: 5463.5908 - loss: -6.1737 - val_log_likelihood_function: 7005.7827 - val_loss: -7.7585
# Epoch 6/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6137.0879 - loss: -6.8415 - val_log_likelihood_function: 7032.9038 - val_loss: -7.7855
# Epoch 7/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5554.3237 - loss: -6.4192 - val_log_likelihood_function: 7282.0684 - val_loss: -8.0271
# Epoch 8/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6158.9932 - loss: -6.7641 - val_log_likelihood_function: 7141.9639 - val_loss: -7.8924
# Epoch 9/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5529.8750 - loss: -6.2406 - val_log_likelihood_function: 7280.3667 - val_loss: -8.0259
# Epoch 10/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5993.5259 - loss: -6.9324 - val_log_likelihood_function: 7220.8955 - val_loss: -7.9684
# Epoch 11/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - log_likelihood_function: 5478.7480 - loss: -6.2494 - val_log_likelihood_function: 7296.3608 - val_loss: -8.0412
# Epoch 12/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6191.6528 - loss: -7.1184 - val_log_likelihood_function: 7307.1797 - val_loss: -8.0515
# Epoch 13/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5580.7339 - loss: -6.4100 - val_log_likelihood_function: 7318.0952 - val_loss: -8.0604
# Epoch 14/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 6191.2373 - loss: -7.0808 - val_log_likelihood_function: 7209.3955 - val_loss: -7.9573
# Epoch 15/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - log_likelihood_function: 5661.9761 - loss: -6.4976 - val_log_likelihood_function: 7151.4019 - val_loss: -7.8999
# Epoch 16/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - log_likelihood_function: 6252.9463 - loss: -7.0486 - val_log_likelihood_function: 7268.0059 - val_loss: -8.0140
# Epoch 17/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - log_likelihood_function: 5569.9790 - loss: -6.4568 - val_log_likelihood_function: 7366.7109 - val_loss: -8.1096
# Epoch 18/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6127.4077 - loss: -6.8244 - val_log_likelihood_function: 7160.6562 - val_loss: -7.9110
# Epoch 19/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - log_likelihood_function: 5542.9243 - loss: -6.3049 - val_log_likelihood_function: 7315.8008 - val_loss: -8.0602
# Epoch 20/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6105.0864 - loss: -6.6210 - val_log_likelihood_function: 7191.4517 - val_loss: -7.9407
# Epoch 21/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - log_likelihood_function: 5404.6055 - loss: -6.1858 - val_log_likelihood_function: 7294.8403 - val_loss: -8.0410
# Epoch 22/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6188.1748 - loss: -7.0127 - val_log_likelihood_function: 7261.6040 - val_loss: -8.0104
# Epoch 23/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5519.5430 - loss: -6.4980 - val_log_likelihood_function: 7297.0415 - val_loss: -8.0431
# Epoch 24/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6259.3813 - loss: -6.9319 - val_log_likelihood_function: 7256.2729 - val_loss: -8.0044
# Epoch 25/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - log_likelihood_function: 5810.5591 - loss: -6.5571 - val_log_likelihood_function: 7275.4629 - val_loss: -8.0215
# Epoch 26/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6097.0020 - loss: -6.8338 - val_log_likelihood_function: 7220.3960 - val_loss: -7.9685
# Epoch 27/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - log_likelihood_function: 5620.7402 - loss: -6.4808 - val_log_likelihood_function: 7300.5186 - val_loss: -8.0459
# Epoch 28/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6295.4565 - loss: -7.0378 - val_log_likelihood_function: 7196.5962 - val_loss: -7.9473
# Epoch 29/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 5556.3687 - loss: -6.3490 - val_log_likelihood_function: 7272.3203 - val_loss: -8.0196
# Epoch 30/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - log_likelihood_function: 6225.8237 - loss: -6.8710 - val_log_likelihood_function: 7164.0151 - val_loss: -7.9151
# Epoch 31/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5548.3125 - loss: -6.5062 - val_log_likelihood_function: 7302.9224 - val_loss: -8.0507
# Epoch 32/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - log_likelihood_function: 6156.4209 - loss: -7.2294 - val_log_likelihood_function: 7335.2466 - val_loss: -8.0836
# Epoch 33/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5491.6621 - loss: -6.4288 - val_log_likelihood_function: 7279.8623 - val_loss: -8.0247
# Epoch 34/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - log_likelihood_function: 6145.0088 - loss: -7.0391 - val_log_likelihood_function: 7260.2476 - val_loss: -8.0069
# Epoch 35/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5587.2983 - loss: -6.4044 - val_log_likelihood_function: 7173.9639 - val_loss: -7.9214
# Epoch 36/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6065.4956 - loss: -6.7705 - val_log_likelihood_function: 7152.4268 - val_loss: -7.9017
# Epoch 37/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5705.4043 - loss: -6.5202 - val_log_likelihood_function: 7250.3735 - val_loss: -7.9963
# Epoch 38/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6272.5615 - loss: -7.0916 - val_log_likelihood_function: 7237.8193 - val_loss: -7.9857
# Epoch 39/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5718.8105 - loss: -6.5434 - val_log_likelihood_function: 7345.0161 - val_loss: -8.0872
# Epoch 40/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - log_likelihood_function: 6207.2607 - loss: -6.8075 - val_log_likelihood_function: 7165.2222 - val_loss: -7.9145
# Epoch 41/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5549.1665 - loss: -6.4329 - val_log_likelihood_function: 7342.5635 - val_loss: -8.0858
# Epoch 42/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6179.0845 - loss: -6.6362 - val_log_likelihood_function: 7190.0337 - val_loss: -7.9393
# Epoch 43/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5728.0181 - loss: -6.5209 - val_log_likelihood_function: 7337.1953 - val_loss: -8.0820
# Epoch 44/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - log_likelihood_function: 6087.9834 - loss: -7.1006 - val_log_likelihood_function: 7293.9458 - val_loss: -8.0421
# Epoch 45/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5618.2427 - loss: -6.4458 - val_log_likelihood_function: 7347.3335 - val_loss: -8.0891
# Epoch 46/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6163.7510 - loss: -6.9530 - val_log_likelihood_function: 7269.1421 - val_loss: -8.0157
# Epoch 47/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5361.6221 - loss: -6.0951 - val_log_likelihood_function: 7365.0923 - val_loss: -8.1095
# Epoch 48/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6079.0967 - loss: -7.0160 - val_log_likelihood_function: 7290.6108 - val_loss: -8.0396
# Epoch 49/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5526.3569 - loss: -6.2839 - val_log_likelihood_function: 7340.6611 - val_loss: -8.0865
# Epoch 50/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6275.9546 - loss: -6.9860 - val_log_likelihood_function: 7227.7798 - val_loss: -7.9791
# Epoch 51/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5598.6831 - loss: -6.1814 - val_log_likelihood_function: 7302.5801 - val_loss: -8.0522
# Epoch 52/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6198.9331 - loss: -6.5997 - val_log_likelihood_function: 7093.6782 - val_loss: -7.8485
# Epoch 53/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5673.2075 - loss: -6.4278 - val_log_likelihood_function: 7259.9976 - val_loss: -8.0105
# Epoch 54/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6263.9771 - loss: -7.0943 - val_log_likelihood_function: 7225.7729 - val_loss: -7.9792
# Epoch 55/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5612.4556 - loss: -6.4210 - val_log_likelihood_function: 7209.0298 - val_loss: -7.9590
# Epoch 56/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6268.7637 - loss: -6.9477 - val_log_likelihood_function: 7168.8945 - val_loss: -7.9213
# Epoch 57/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5655.1787 - loss: -6.5089 - val_log_likelihood_function: 7302.0151 - val_loss: -8.0508
# Epoch 58/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6135.7158 - loss: -7.0679 - val_log_likelihood_function: 7242.7998 - val_loss: -7.9950
# Epoch 59/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5543.7314 - loss: -6.3880 - val_log_likelihood_function: 7126.4111 - val_loss: -7.8791
# Epoch 60/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - log_likelihood_function: 6319.8589 - loss: -7.0753 - val_log_likelihood_function: 7254.0420 - val_loss: -8.0065
# Epoch 61/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5415.6479 - loss: -6.2308 - val_log_likelihood_function: 7348.9492 - val_loss: -8.0973
# Epoch 62/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - log_likelihood_function: 6138.3506 - loss: -6.9096 - val_log_likelihood_function: 7273.4756 - val_loss: -8.0250
# Epoch 63/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5793.3120 - loss: -6.5690 - val_log_likelihood_function: 7335.7173 - val_loss: -8.0858
# Epoch 64/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6259.5757 - loss: -6.8565 - val_log_likelihood_function: 7238.9604 - val_loss: -7.9921
# Epoch 65/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5687.9565 - loss: -6.4623 - val_log_likelihood_function: 7330.5928 - val_loss: -8.0808
# Epoch 66/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6216.5269 - loss: -6.8888 - val_log_likelihood_function: 7193.4268 - val_loss: -7.9484
# Epoch 67/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5821.5518 - loss: -6.4953 - val_log_likelihood_function: 7350.6670 - val_loss: -8.1010
# Epoch 68/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 5986.8101 - loss: -6.3883 - val_log_likelihood_function: 7140.7119 - val_loss: -7.8971
# Epoch 69/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5495.6948 - loss: -6.2252 - val_log_likelihood_function: 7284.0068 - val_loss: -8.0344
# Epoch 70/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6209.9082 - loss: -7.0057 - val_log_likelihood_function: 7266.8521 - val_loss: -8.0205
# Epoch 71/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5653.8784 - loss: -6.5120 - val_log_likelihood_function: 7262.2349 - val_loss: -8.0136
# Epoch 72/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6323.3384 - loss: -6.9190 - val_log_likelihood_function: 7250.0659 - val_loss: -8.0039
# Epoch 73/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5624.6479 - loss: -6.5020 - val_log_likelihood_function: 7284.3955 - val_loss: -8.0354
# Epoch 74/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6237.2290 - loss: -7.2635 - val_log_likelihood_function: 7293.5742 - val_loss: -8.0489
# Epoch 75/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5737.1948 - loss: -6.5167 - val_log_likelihood_function: 7310.0576 - val_loss: -8.0635
# Epoch 76/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6220.7886 - loss: -7.0028 - val_log_likelihood_function: 7289.0312 - val_loss: -8.0446
# Epoch 77/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5565.0879 - loss: -6.2970 - val_log_likelihood_function: 7314.4966 - val_loss: -8.0639
# Epoch 78/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6220.4209 - loss: -6.7394 - val_log_likelihood_function: 7160.2651 - val_loss: -7.9145
# Epoch 79/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5728.4521 - loss: -6.5016 - val_log_likelihood_function: 7347.9746 - val_loss: -8.0971
# Epoch 80/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6207.4917 - loss: -6.8891 - val_log_likelihood_function: 7182.9766 - val_loss: -7.9383
# Epoch 81/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5615.0913 - loss: -6.4851 - val_log_likelihood_function: 7315.5547 - val_loss: -8.0681
# Epoch 82/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - log_likelihood_function: 6245.2510 - loss: -6.9923 - val_log_likelihood_function: 7277.2798 - val_loss: -8.0309
# Epoch 83/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5645.3325 - loss: -6.4412 - val_log_likelihood_function: 7286.6860 - val_loss: -8.0390
# Epoch 84/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6253.9619 - loss: -7.0857 - val_log_likelihood_function: 7229.8076 - val_loss: -7.9848
# Epoch 85/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5561.8555 - loss: -6.3271 - val_log_likelihood_function: 7369.0786 - val_loss: -8.1167
# Epoch 86/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6359.3364 - loss: -7.2007 - val_log_likelihood_function: 7343.8286 - val_loss: -8.0973
# Epoch 87/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5841.5322 - loss: -6.6389 - val_log_likelihood_function: 7316.8926 - val_loss: -8.0629
# Epoch 88/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6255.3257 - loss: -7.1208 - val_log_likelihood_function: 7264.4839 - val_loss: -8.0161
# Epoch 89/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5825.8877 - loss: -6.6526 - val_log_likelihood_function: 7335.4551 - val_loss: -8.0819
# Epoch 90/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6244.6201 - loss: -6.7954 - val_log_likelihood_function: 7233.4272 - val_loss: -7.9838
# Epoch 91/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5537.2554 - loss: -6.3736 - val_log_likelihood_function: 7313.3208 - val_loss: -8.0638
# Epoch 92/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6287.6187 - loss: -7.0606 - val_log_likelihood_function: 7296.7456 - val_loss: -8.0499
# Epoch 93/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5744.4849 - loss: -6.5889 - val_log_likelihood_function: 7338.6260 - val_loss: -8.0867
# Epoch 94/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6194.3477 - loss: -7.0336 - val_log_likelihood_function: 7256.2637 - val_loss: -8.0106
# Epoch 95/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5507.3862 - loss: -6.2839 - val_log_likelihood_function: 7298.9922 - val_loss: -8.0471
# Epoch 96/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6343.4907 - loss: -7.1972 - val_log_likelihood_function: 7306.1699 - val_loss: -8.0608
# Epoch 97/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5786.0737 - loss: -6.6164 - val_log_likelihood_function: 7295.5220 - val_loss: -8.0465
# Epoch 98/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6219.0903 - loss: -7.2214 - val_log_likelihood_function: 7318.2812 - val_loss: -8.0717
# Epoch 99/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5842.5332 - loss: -6.5084 - val_log_likelihood_function: 7328.2085 - val_loss: -8.0777
# Epoch 100/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6214.0215 - loss: -7.0748 - val_log_likelihood_function: 7224.1006 - val_loss: -7.9793
# Epoch 101/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5735.5996 - loss: -6.5388 - val_log_likelihood_function: 7374.1548 - val_loss: -8.1263
# Epoch 102/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6276.6416 - loss: -7.1541 - val_log_likelihood_function: 7305.6772 - val_loss: -8.0636
# Epoch 103/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5658.9111 - loss: -6.5302 - val_log_likelihood_function: 7283.7915 - val_loss: -8.0340
# Epoch 104/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - log_likelihood_function: 6237.3486 - loss: -7.1094 - val_log_likelihood_function: 7295.6157 - val_loss: -8.0521
# Epoch 105/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5873.8975 - loss: -6.7240 - val_log_likelihood_function: 7226.9214 - val_loss: -7.9757
# Epoch 106/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6264.3457 - loss: -6.9597 - val_log_likelihood_function: 7237.7764 - val_loss: -7.9885
# Epoch 107/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5737.4214 - loss: -6.5192 - val_log_likelihood_function: 7379.7139 - val_loss: -8.1318
# Epoch 108/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6236.5298 - loss: -6.8370 - val_log_likelihood_function: 7185.4390 - val_loss: -7.9451
# Epoch 109/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5747.2461 - loss: -6.5745 - val_log_likelihood_function: 7348.9155 - val_loss: -8.0987
# Epoch 110/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6196.2271 - loss: -6.8520 - val_log_likelihood_function: 7195.0854 - val_loss: -7.9544
# Epoch 111/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5680.8394 - loss: -6.5575 - val_log_likelihood_function: 7388.9756 - val_loss: -8.1450
# Epoch 112/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6231.5186 - loss: -7.0495 - val_log_likelihood_function: 7248.0405 - val_loss: -8.0105
# Epoch 113/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5697.7622 - loss: -6.4578 - val_log_likelihood_function: 7350.3203 - val_loss: -8.1044
# Epoch 114/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6287.1206 - loss: -7.0654 - val_log_likelihood_function: 7202.5186 - val_loss: -7.9629
# Epoch 115/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5864.2637 - loss: -6.7075 - val_log_likelihood_function: 7385.5186 - val_loss: -8.1395
# Epoch 116/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - log_likelihood_function: 6291.4839 - loss: -7.0303 - val_log_likelihood_function: 7296.3159 - val_loss: -8.0548
# Epoch 117/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5619.4766 - loss: -6.6052 - val_log_likelihood_function: 7321.8936 - val_loss: -8.0749
# Epoch 118/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6333.1802 - loss: -7.0146 - val_log_likelihood_function: 7244.7720 - val_loss: -8.0090
# Epoch 119/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5865.6133 - loss: -6.7068 - val_log_likelihood_function: 7319.8193 - val_loss: -8.0711
# Epoch 120/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - log_likelihood_function: 6277.1499 - loss: -7.0381 - val_log_likelihood_function: 7243.7671 - val_loss: -8.0035
# Epoch 121/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5871.0146 - loss: -6.5761 - val_log_likelihood_function: 7319.5244 - val_loss: -8.0726
# Epoch 122/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - log_likelihood_function: 6356.9155 - loss: -7.0793 - val_log_likelihood_function: 7330.3203 - val_loss: -8.0930
# Epoch 123/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5842.0059 - loss: -6.6704 - val_log_likelihood_function: 7353.0718 - val_loss: -8.1044
# Epoch 124/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - log_likelihood_function: 6186.4170 - loss: -7.0853 - val_log_likelihood_function: 7303.3125 - val_loss: -8.0648
# Epoch 125/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5886.4214 - loss: -6.7034 - val_log_likelihood_function: 7355.1226 - val_loss: -8.1031
# Epoch 126/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6329.1641 - loss: -6.8607 - val_log_likelihood_function: 7267.3345 - val_loss: -8.0230
# Epoch 127/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5713.8379 - loss: -6.6412 - val_log_likelihood_function: 7212.2939 - val_loss: -7.9623
# Epoch 128/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6371.4849 - loss: -7.1144 - val_log_likelihood_function: 7322.7671 - val_loss: -8.0778
# Epoch 129/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5850.4185 - loss: -6.6997 - val_log_likelihood_function: 7310.9019 - val_loss: -8.0588
# Epoch 130/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6358.6035 - loss: -7.2847 - val_log_likelihood_function: 7359.5337 - val_loss: -8.1111
# Epoch 131/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5832.5234 - loss: -6.6482 - val_log_likelihood_function: 7352.8647 - val_loss: -8.1012
# Epoch 132/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - log_likelihood_function: 6310.9790 - loss: -7.1242 - val_log_likelihood_function: 7277.9224 - val_loss: -8.0371
# Epoch 133/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5840.6094 - loss: -6.7248 - val_log_likelihood_function: 7230.4341 - val_loss: -7.9848
# Epoch 134/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6368.9810 - loss: -7.1099 - val_log_likelihood_function: 7300.7515 - val_loss: -8.0609
# Epoch 135/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5928.7363 - loss: -6.9072 - val_log_likelihood_function: 7360.7144 - val_loss: -8.1108
# Epoch 136/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6355.2588 - loss: -7.1022 - val_log_likelihood_function: 7259.4780 - val_loss: -8.0250
# Epoch 137/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5958.6665 - loss: -6.7842 - val_log_likelihood_function: 7366.2568 - val_loss: -8.1153
# Epoch 138/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6357.2456 - loss: -7.1319 - val_log_likelihood_function: 7317.6436 - val_loss: -8.0804
# Epoch 139/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6063.2710 - loss: -6.8538 - val_log_likelihood_function: 7365.2856 - val_loss: -8.1113
# Epoch 140/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6359.1919 - loss: -7.0988 - val_log_likelihood_function: 7290.5796 - val_loss: -8.0527
# Epoch 141/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 5961.7539 - loss: -6.9438 - val_log_likelihood_function: 7379.8115 - val_loss: -8.1343
# Epoch 142/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6311.4468 - loss: -7.0097 - val_log_likelihood_function: 7251.2964 - val_loss: -8.0179
# Epoch 143/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5896.0225 - loss: -6.7815 - val_log_likelihood_function: 7311.7466 - val_loss: -8.0561
# Epoch 144/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6421.6567 - loss: -7.0304 - val_log_likelihood_function: 7250.2871 - val_loss: -8.0001
# Epoch 145/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 5968.1592 - loss: -6.9082 - val_log_likelihood_function: 7306.2144 - val_loss: -8.0633
# Epoch 146/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6361.6406 - loss: -7.0510 - val_log_likelihood_function: 7274.9688 - val_loss: -8.0374
# Epoch 147/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5972.1880 - loss: -6.7956 - val_log_likelihood_function: 7313.8926 - val_loss: -8.0631
# Epoch 148/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6327.1650 - loss: -6.9123 - val_log_likelihood_function: 7256.4351 - val_loss: -8.0129
# Epoch 149/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5981.5703 - loss: -6.8639 - val_log_likelihood_function: 7397.4814 - val_loss: -8.1514
# Epoch 150/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - log_likelihood_function: 6308.8989 - loss: -7.2087 - val_log_likelihood_function: 7326.9609 - val_loss: -8.0993
# Epoch 151/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6046.5229 - loss: -6.9339 - val_log_likelihood_function: 7386.9087 - val_loss: -8.1395
# Epoch 152/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6324.5552 - loss: -7.1393 - val_log_likelihood_function: 7306.0298 - val_loss: -8.0745
# Epoch 153/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5935.2793 - loss: -6.7929 - val_log_likelihood_function: 7417.1006 - val_loss: -8.1682
# Epoch 154/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - log_likelihood_function: 6338.2026 - loss: -7.2750 - val_log_likelihood_function: 7396.8286 - val_loss: -8.1673
# Epoch 155/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 5989.7021 - loss: -6.8593 - val_log_likelihood_function: 7388.2305 - val_loss: -8.1490
# Epoch 156/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6412.6851 - loss: -7.1959 - val_log_likelihood_function: 7276.8369 - val_loss: -8.0476
# Epoch 157/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6076.5762 - loss: -6.9574 - val_log_likelihood_function: 7348.1919 - val_loss: -8.1002
# Epoch 158/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - log_likelihood_function: 6423.9438 - loss: -7.1132 - val_log_likelihood_function: 7339.0186 - val_loss: -8.0968
# Epoch 159/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6007.2466 - loss: -6.8311 - val_log_likelihood_function: 7403.3911 - val_loss: -8.1712
# Epoch 160/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - log_likelihood_function: 6397.3730 - loss: -7.1761 - val_log_likelihood_function: 7383.0083 - val_loss: -8.1591
# Epoch 161/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 5925.8652 - loss: -6.7992 - val_log_likelihood_function: 7341.7583 - val_loss: -8.1015
# Epoch 162/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6350.7710 - loss: -6.9589 - val_log_likelihood_function: 7293.5205 - val_loss: -8.0600
# Epoch 163/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6027.9717 - loss: -6.8853 - val_log_likelihood_function: 7317.4307 - val_loss: -8.0698
# Epoch 164/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - log_likelihood_function: 6375.9004 - loss: -7.2187 - val_log_likelihood_function: 7305.7441 - val_loss: -8.0773
# Epoch 165/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6188.1548 - loss: -7.0235 - val_log_likelihood_function: 7421.3506 - val_loss: -8.1656
# Epoch 166/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6355.8071 - loss: -6.9293 - val_log_likelihood_function: 7321.2861 - val_loss: -8.0763
# Epoch 167/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5952.5088 - loss: -6.9328 - val_log_likelihood_function: 7402.4712 - val_loss: -8.1595
# Epoch 168/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6374.7568 - loss: -7.2621 - val_log_likelihood_function: 7369.0703 - val_loss: -8.1516
# Epoch 169/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6066.2563 - loss: -7.0239 - val_log_likelihood_function: 7326.0635 - val_loss: -8.0739
# Epoch 170/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - log_likelihood_function: 6390.3799 - loss: -7.2360 - val_log_likelihood_function: 7309.9629 - val_loss: -8.0744
# Epoch 171/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 5975.8501 - loss: -6.9113 - val_log_likelihood_function: 7377.7603 - val_loss: -8.1312
# Epoch 172/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6403.5166 - loss: -7.1781 - val_log_likelihood_function: 7370.6494 - val_loss: -8.1375
# Epoch 173/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6122.0171 - loss: -7.0434 - val_log_likelihood_function: 7381.1841 - val_loss: -8.1295
# Epoch 174/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6474.1494 - loss: -7.2419 - val_log_likelihood_function: 7356.4268 - val_loss: -8.1268
# Epoch 175/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6096.3979 - loss: -7.0540 - val_log_likelihood_function: 7367.9385 - val_loss: -8.1216
# Epoch 176/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6387.7920 - loss: -7.1879 - val_log_likelihood_function: 7368.8691 - val_loss: -8.1482
# Epoch 177/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6179.7422 - loss: -7.1524 - val_log_likelihood_function: 7412.4326 - val_loss: -8.1682
# Epoch 178/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6337.4844 - loss: -7.0913 - val_log_likelihood_function: 7313.1606 - val_loss: -8.0869
# Epoch 179/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6091.3730 - loss: -7.0858 - val_log_likelihood_function: 7325.0264 - val_loss: -8.0808
# Epoch 180/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6410.6768 - loss: -7.1934 - val_log_likelihood_function: 7365.3472 - val_loss: -8.1373
# Epoch 181/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6116.3267 - loss: -7.0897 - val_log_likelihood_function: 7314.3833 - val_loss: -8.0718
# Epoch 182/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - log_likelihood_function: 6318.6494 - loss: -6.8760 - val_log_likelihood_function: 7284.6064 - val_loss: -8.0490
# Epoch 183/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6167.2905 - loss: -7.1034 - val_log_likelihood_function: 7334.8701 - val_loss: -8.1017
# Epoch 184/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6407.4375 - loss: -7.0993 - val_log_likelihood_function: 7295.5801 - val_loss: -8.0718
# Epoch 185/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6206.3076 - loss: -7.0673 - val_log_likelihood_function: 7405.1226 - val_loss: -8.1603
# Epoch 186/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6423.5513 - loss: -6.9847 - val_log_likelihood_function: 7270.9028 - val_loss: -8.0360
# Epoch 187/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 5847.7119 - loss: -6.5782 - val_log_likelihood_function: 7303.9956 - val_loss: -8.0686
# Epoch 188/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6327.0830 - loss: -6.9451 - val_log_likelihood_function: 7262.5703 - val_loss: -8.0285
# Epoch 189/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6128.6797 - loss: -7.0556 - val_log_likelihood_function: 7331.1201 - val_loss: -8.0927
# Epoch 190/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6432.5039 - loss: -7.2936 - val_log_likelihood_function: 7383.9849 - val_loss: -8.1587
# Epoch 191/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6025.1304 - loss: -6.9334 - val_log_likelihood_function: 7300.2197 - val_loss: -8.0682
# Epoch 192/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6446.4717 - loss: -7.2351 - val_log_likelihood_function: 7391.2896 - val_loss: -8.1668
# Epoch 193/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6228.9639 - loss: -7.2238 - val_log_likelihood_function: 7310.0830 - val_loss: -8.0727
# Epoch 194/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6354.2749 - loss: -7.0710 - val_log_likelihood_function: 7287.7314 - val_loss: -8.0615
# Epoch 195/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6190.4907 - loss: -7.1535 - val_log_likelihood_function: 7340.6113 - val_loss: -8.1023
# Epoch 196/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - log_likelihood_function: 6340.5571 - loss: -7.2859 - val_log_likelihood_function: 7417.0298 - val_loss: -8.1912
# Epoch 197/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6143.4839 - loss: -7.1741 - val_log_likelihood_function: 7437.9292 - val_loss: -8.1927
# Epoch 198/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6407.0264 - loss: -7.2262 - val_log_likelihood_function: 7411.7603 - val_loss: -8.1837
# Epoch 199/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6198.9878 - loss: -7.1774 - val_log_likelihood_function: 7392.4756 - val_loss: -8.1593
# Epoch 200/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6404.6460 - loss: -7.1543 - val_log_likelihood_function: 7398.9829 - val_loss: -8.1812
# Epoch 201/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6127.9185 - loss: -7.1509 - val_log_likelihood_function: 7436.8262 - val_loss: -8.1856
# Epoch 202/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6340.9028 - loss: -7.0819 - val_log_likelihood_function: 7360.7896 - val_loss: -8.1342
# Epoch 203/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6160.8008 - loss: -7.1383 - val_log_likelihood_function: 7345.4316 - val_loss: -8.1022
# Epoch 204/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6417.1475 - loss: -7.2888 - val_log_likelihood_function: 7389.9790 - val_loss: -8.1678
# Epoch 205/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6197.9434 - loss: -7.1643 - val_log_likelihood_function: 7401.4165 - val_loss: -8.1727
# Epoch 206/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - log_likelihood_function: 6389.5098 - loss: -7.0507 - val_log_likelihood_function: 7305.4097 - val_loss: -8.0923
# Epoch 207/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6134.4658 - loss: -7.1313 - val_log_likelihood_function: 7398.7607 - val_loss: -8.1583
# Epoch 208/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - log_likelihood_function: 6425.3169 - loss: -6.9283 - val_log_likelihood_function: 7280.9399 - val_loss: -8.0476
# Epoch 209/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6097.9316 - loss: -7.0930 - val_log_likelihood_function: 7425.2393 - val_loss: -8.1877
# Epoch 210/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6363.7080 - loss: -7.0352 - val_log_likelihood_function: 7338.5137 - val_loss: -8.1090
# Epoch 211/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6132.8394 - loss: -7.0070 - val_log_likelihood_function: 7442.3877 - val_loss: -8.2039
# Epoch 212/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6328.4614 - loss: -7.1615 - val_log_likelihood_function: 7378.0312 - val_loss: -8.1501
# Epoch 213/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6191.4990 - loss: -7.1588 - val_log_likelihood_function: 7432.0972 - val_loss: -8.1978
# Epoch 214/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - log_likelihood_function: 6419.3320 - loss: -7.0428 - val_log_likelihood_function: 7259.1606 - val_loss: -8.0425
# Epoch 215/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6273.1602 - loss: -7.2203 - val_log_likelihood_function: 7398.5786 - val_loss: -8.1594
# Epoch 216/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - log_likelihood_function: 6386.1484 - loss: -6.9732 - val_log_likelihood_function: 7318.1074 - val_loss: -8.0944
# Epoch 217/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6205.5054 - loss: -7.1938 - val_log_likelihood_function: 7433.4106 - val_loss: -8.1917
# Epoch 218/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6462.0786 - loss: -7.3845 - val_log_likelihood_function: 7460.8379 - val_loss: -8.2472
# Epoch 219/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6141.4692 - loss: -7.1135 - val_log_likelihood_function: 7423.9653 - val_loss: -8.1769
# Epoch 220/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - log_likelihood_function: 6445.3481 - loss: -7.0258 - val_log_likelihood_function: 7362.4512 - val_loss: -8.1338
# Epoch 221/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6157.8477 - loss: -7.1768 - val_log_likelihood_function: 7369.3716 - val_loss: -8.1257
# Epoch 222/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6482.4175 - loss: -7.1430 - val_log_likelihood_function: 7336.0947 - val_loss: -8.1173
# Epoch 223/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6118.8447 - loss: -7.0466 - val_log_likelihood_function: 7355.3921 - val_loss: -8.1238
# Epoch 224/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6375.6870 - loss: -7.2450 - val_log_likelihood_function: 7392.0498 - val_loss: -8.1787
# Epoch 225/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6263.4312 - loss: -7.2737 - val_log_likelihood_function: 7440.5649 - val_loss: -8.2073
# Epoch 226/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - log_likelihood_function: 6469.3008 - loss: -7.1323 - val_log_likelihood_function: 7388.4482 - val_loss: -8.1681
# Epoch 227/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6108.2500 - loss: -7.1370 - val_log_likelihood_function: 7431.0518 - val_loss: -8.1996
# Epoch 228/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6341.8213 - loss: -7.2704 - val_log_likelihood_function: 7397.5693 - val_loss: -8.1699
# Epoch 229/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6232.1851 - loss: -7.2730 - val_log_likelihood_function: 7390.8979 - val_loss: -8.1441
# Epoch 230/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6490.7202 - loss: -7.2658 - val_log_likelihood_function: 7401.9077 - val_loss: -8.1684
# Epoch 231/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6056.0000 - loss: -7.1196 - val_log_likelihood_function: 7390.0889 - val_loss: -8.1525
# Epoch 232/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6465.5854 - loss: -7.2817 - val_log_likelihood_function: 7418.0454 - val_loss: -8.1851
# Epoch 233/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6222.8604 - loss: -7.1593 - val_log_likelihood_function: 7431.7705 - val_loss: -8.1792
# Epoch 234/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6413.0312 - loss: -7.1895 - val_log_likelihood_function: 7299.9873 - val_loss: -8.0712
# Epoch 235/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6175.9819 - loss: -7.1201 - val_log_likelihood_function: 7381.5610 - val_loss: -8.1470
# Epoch 236/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6445.6387 - loss: -7.0092 - val_log_likelihood_function: 7348.1260 - val_loss: -8.1129
# Epoch 237/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - log_likelihood_function: 6272.3149 - loss: -7.1981 - val_log_likelihood_function: 7420.8887 - val_loss: -8.1682
# Epoch 238/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6437.2490 - loss: -7.1288 - val_log_likelihood_function: 7399.0220 - val_loss: -8.1646
# Epoch 239/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 6152.9009 - loss: -7.2342 - val_log_likelihood_function: 7381.2080 - val_loss: -8.1298
# Epoch 240/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6529.1890 - loss: -7.1443 - val_log_likelihood_function: 7359.2744 - val_loss: -8.1322
# Epoch 241/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6298.9023 - loss: -7.3098 - val_log_likelihood_function: 7386.0337 - val_loss: -8.1476
# Epoch 242/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6438.8408 - loss: -7.1285 - val_log_likelihood_function: 7399.0034 - val_loss: -8.1666
# Epoch 243/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6070.5122 - loss: -7.2134 - val_log_likelihood_function: 7403.6978 - val_loss: -8.1594
# Epoch 244/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6492.4365 - loss: -7.0733 - val_log_likelihood_function: 7309.1411 - val_loss: -8.0789
# Epoch 245/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6227.0269 - loss: -7.1802 - val_log_likelihood_function: 7347.6631 - val_loss: -8.1051
# Epoch 246/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6475.5688 - loss: -7.3078 - val_log_likelihood_function: 7436.0059 - val_loss: -8.2024
# Epoch 247/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6284.3486 - loss: -7.2657 - val_log_likelihood_function: 7419.3149 - val_loss: -8.1799
# Epoch 248/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6450.5205 - loss: -7.1516 - val_log_likelihood_function: 7350.4385 - val_loss: -8.1246
# Epoch 249/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6266.4868 - loss: -7.3114 - val_log_likelihood_function: 7413.7305 - val_loss: -8.1790
# Epoch 250/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - log_likelihood_function: 6515.0225 - loss: -7.2822 - val_log_likelihood_function: 7437.1504 - val_loss: -8.2215
# Epoch 251/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6144.5928 - loss: -7.2525 - val_log_likelihood_function: 7351.3242 - val_loss: -8.1150
# Epoch 252/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6487.4771 - loss: -7.3251 - val_log_likelihood_function: 7424.8911 - val_loss: -8.1954
# Epoch 253/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - log_likelihood_function: 6230.6597 - loss: -7.2245 - val_log_likelihood_function: 7446.1943 - val_loss: -8.2109
# Epoch 254/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6451.4185 - loss: -7.0972 - val_log_likelihood_function: 7378.9053 - val_loss: -8.1532
# Epoch 255/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6202.1426 - loss: -7.2301 - val_log_likelihood_function: 7383.2349 - val_loss: -8.1455
# Epoch 256/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6448.2256 - loss: -7.0779 - val_log_likelihood_function: 7360.5566 - val_loss: -8.1295
# Epoch 257/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6153.7378 - loss: -7.0431 - val_log_likelihood_function: 7432.4155 - val_loss: -8.1944
# Epoch 258/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6466.6641 - loss: -7.2768 - val_log_likelihood_function: 7394.0835 - val_loss: -8.1698
# Epoch 259/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6221.4761 - loss: -7.2997 - val_log_likelihood_function: 7414.2744 - val_loss: -8.1710
# Epoch 260/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6467.8979 - loss: -7.1831 - val_log_likelihood_function: 7409.7363 - val_loss: -8.1841
# Epoch 261/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6224.3677 - loss: -7.2035 - val_log_likelihood_function: 7405.5742 - val_loss: -8.1746
# Epoch 262/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6503.7651 - loss: -7.2628 - val_log_likelihood_function: 7380.6968 - val_loss: -8.1647
# Epoch 263/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6133.7158 - loss: -7.1660 - val_log_likelihood_function: 7450.7178 - val_loss: -8.2076
# Epoch 264/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6472.5122 - loss: -7.1830 - val_log_likelihood_function: 7369.7095 - val_loss: -8.1396
# Epoch 265/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6289.5527 - loss: -7.2340 - val_log_likelihood_function: 7397.7847 - val_loss: -8.1585
# Epoch 266/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - log_likelihood_function: 6476.9570 - loss: -7.3927 - val_log_likelihood_function: 7443.5000 - val_loss: -8.2270
# Epoch 267/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6048.4307 - loss: -7.2767 - val_log_likelihood_function: 7442.4282 - val_loss: -8.2152
# Epoch 268/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6421.9131 - loss: -7.2223 - val_log_likelihood_function: 7361.4712 - val_loss: -8.1496
# Epoch 269/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6313.8003 - loss: -7.3036 - val_log_likelihood_function: 7418.3462 - val_loss: -8.1835
# Epoch 270/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6520.8149 - loss: -7.2057 - val_log_likelihood_function: 7397.8760 - val_loss: -8.1836
# Epoch 271/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6248.2588 - loss: -7.2658 - val_log_likelihood_function: 7404.6519 - val_loss: -8.1701
# Epoch 272/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6516.2456 - loss: -7.1771 - val_log_likelihood_function: 7364.5801 - val_loss: -8.1374
# Epoch 273/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6279.5342 - loss: -7.3535 - val_log_likelihood_function: 7414.6436 - val_loss: -8.1814
# Epoch 274/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6470.1650 - loss: -7.2526 - val_log_likelihood_function: 7376.6299 - val_loss: -8.1640
# Epoch 275/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6298.9121 - loss: -7.2181 - val_log_likelihood_function: 7466.0938 - val_loss: -8.2355
# Epoch 276/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6510.1167 - loss: -7.2004 - val_log_likelihood_function: 7403.8159 - val_loss: -8.1885
# Epoch 277/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6261.6841 - loss: -7.2402 - val_log_likelihood_function: 7444.1016 - val_loss: -8.1910
# Epoch 278/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - log_likelihood_function: 6492.6216 - loss: -7.2263 - val_log_likelihood_function: 7395.0439 - val_loss: -8.1781
# Epoch 279/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6283.4639 - loss: -7.3290 - val_log_likelihood_function: 7461.0186 - val_loss: -8.2195
# Epoch 280/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6542.3560 - loss: -7.2871 - val_log_likelihood_function: 7429.5913 - val_loss: -8.2044
# Epoch 281/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 6234.3506 - loss: -7.2259 - val_log_likelihood_function: 7434.9526 - val_loss: -8.1842
# Epoch 282/500
# ...
# Epoch 408/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6616.7217 - loss: -7.4363 - val_log_likelihood_function: 7450.7534 - val_loss: -8.2353
# Epoch 409/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6447.9238 - loss: -7.4283 - val_log_likelihood_function: 7469.0391 - val_loss: -8.2409
# Epoch 410/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6611.9355 - loss: -7.4096 - val_log_likelihood_function: 7453.2827 - val_loss: -8.2407
# Epoch 411/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6461.3506 - loss: -7.4815 - val_log_likelihood_function: 7478.4048 - val_loss: -8.2417
# Epoch 412/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - log_likelihood_function: 6592.0571 - loss: -7.3690 - val_log_likelihood_function: 7469.7432 - val_loss: -8.2519
# Epoch 413/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6393.2622 - loss: -7.4071 - val_log_likelihood_function: 7452.1631 - val_loss: -8.2193
# Epoch 414/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6568.6558 - loss: -7.2909 - val_log_likelihood_function: 7418.9121 - val_loss: -8.1919
# Epoch 415/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6444.1465 - loss: -7.4439 - val_log_likelihood_function: 7473.9282 - val_loss: -8.2405
# Epoch 416/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6591.6689 - loss: -7.4136 - val_log_likelihood_function: 7465.1353 - val_loss: -8.2500
# Epoch 417/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6407.1870 - loss: -7.4741 - val_log_likelihood_function: 7476.3867 - val_loss: -8.2415
# Epoch 418/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6599.7578 - loss: -7.3980 - val_log_likelihood_function: 7462.8267 - val_loss: -8.2490
# Epoch 419/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6370.2627 - loss: -7.4550 - val_log_likelihood_function: 7435.7549 - val_loss: -8.1936
# Epoch 420/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6619.2920 - loss: -7.4376 - val_log_likelihood_function: 7448.1562 - val_loss: -8.2268
# Epoch 421/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 6365.0459 - loss: -7.3631 - val_log_likelihood_function: 7461.8599 - val_loss: -8.2275
# Epoch 422/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6639.3027 - loss: -7.3852 - val_log_likelihood_function: 7456.4619 - val_loss: -8.2344
# Epoch 423/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6349.3071 - loss: -7.4815 - val_log_likelihood_function: 7472.2017 - val_loss: -8.2446
# Epoch 424/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6644.2954 - loss: -7.4335 - val_log_likelihood_function: 7464.1860 - val_loss: -8.2472
# Epoch 425/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6454.5679 - loss: -7.4722 - val_log_likelihood_function: 7481.1426 - val_loss: -8.2570
# Epoch 426/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6616.1147 - loss: -7.3091 - val_log_likelihood_function: 7454.7109 - val_loss: -8.2436
# Epoch 427/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 6425.2349 - loss: -7.4784 - val_log_likelihood_function: 7487.0928 - val_loss: -8.2610
# Epoch 428/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6562.3608 - loss: -7.3595 - val_log_likelihood_function: 7466.9331 - val_loss: -8.2563
# Epoch 429/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6444.1646 - loss: -7.5208 - val_log_likelihood_function: 7492.6470 - val_loss: -8.2640
# Epoch 430/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6590.1733 - loss: -7.3536 - val_log_likelihood_function: 7474.2188 - val_loss: -8.2604
# Epoch 431/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6471.5054 - loss: -7.4690 - val_log_likelihood_function: 7474.3286 - val_loss: -8.2474
# Epoch 432/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - log_likelihood_function: 6629.2715 - loss: -7.3552 - val_log_likelihood_function: 7431.3979 - val_loss: -8.2168
# Epoch 433/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6419.8857 - loss: -7.5305 - val_log_likelihood_function: 7474.8682 - val_loss: -8.2409
# Epoch 434/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - log_likelihood_function: 6620.4585 - loss: -7.4455 - val_log_likelihood_function: 7474.4697 - val_loss: -8.2598
# Epoch 435/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6390.7197 - loss: -7.4598 - val_log_likelihood_function: 7465.6460 - val_loss: -8.2315
# Epoch 436/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6587.5215 - loss: -7.4304 - val_log_likelihood_function: 7469.3486 - val_loss: -8.2577
# Epoch 437/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6456.3657 - loss: -7.4837 - val_log_likelihood_function: 7470.1738 - val_loss: -8.2378
# Epoch 438/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - log_likelihood_function: 6653.7632 - loss: -7.3884 - val_log_likelihood_function: 7470.5601 - val_loss: -8.2553
# Epoch 439/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6436.2788 - loss: -7.5115 - val_log_likelihood_function: 7484.9224 - val_loss: -8.2525
# Epoch 440/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - log_likelihood_function: 6600.6997 - loss: -7.2688 - val_log_likelihood_function: 7458.0142 - val_loss: -8.2360
# Epoch 441/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6465.3896 - loss: -7.4990 - val_log_likelihood_function: 7483.4165 - val_loss: -8.2561
# Epoch 442/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6591.2422 - loss: -7.3874 - val_log_likelihood_function: 7448.3765 - val_loss: -8.2389
# Epoch 443/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6414.9434 - loss: -7.4103 - val_log_likelihood_function: 7467.4028 - val_loss: -8.2432
# Epoch 444/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6667.8125 - loss: -7.4818 - val_log_likelihood_function: 7472.1006 - val_loss: -8.2642
# Epoch 445/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6426.1152 - loss: -7.4906 - val_log_likelihood_function: 7486.0981 - val_loss: -8.2509
# Epoch 446/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6634.5474 - loss: -7.2814 - val_log_likelihood_function: 7470.4917 - val_loss: -8.2511
# Epoch 447/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6284.4946 - loss: -7.2308 - val_log_likelihood_function: 7464.1274 - val_loss: -8.2332
# Epoch 448/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - log_likelihood_function: 6640.5547 - loss: -7.4093 - val_log_likelihood_function: 7451.9619 - val_loss: -8.2381
# Epoch 449/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6498.0205 - loss: -7.5357 - val_log_likelihood_function: 7483.4004 - val_loss: -8.2504
# Epoch 450/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6591.0752 - loss: -7.4577 - val_log_likelihood_function: 7471.1655 - val_loss: -8.2620
# Epoch 451/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6436.3774 - loss: -7.4145 - val_log_likelihood_function: 7477.6909 - val_loss: -8.2445
# Epoch 452/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - log_likelihood_function: 6621.0620 - loss: -7.3878 - val_log_likelihood_function: 7445.6553 - val_loss: -8.2307
# Epoch 453/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6472.6216 - loss: -7.4848 - val_log_likelihood_function: 7479.1665 - val_loss: -8.2410
# Epoch 454/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6622.8213 - loss: -7.4072 - val_log_likelihood_function: 7464.3203 - val_loss: -8.2479
# Epoch 455/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6488.9224 - loss: -7.5180 - val_log_likelihood_function: 7477.5547 - val_loss: -8.2469
# Epoch 456/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - log_likelihood_function: 6663.0117 - loss: -7.4128 - val_log_likelihood_function: 7477.2896 - val_loss: -8.2551
# Epoch 457/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6487.9277 - loss: -7.4968 - val_log_likelihood_function: 7482.4004 - val_loss: -8.2382
# Epoch 458/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6656.9014 - loss: -7.3714 - val_log_likelihood_function: 7475.0010 - val_loss: -8.2499
# Epoch 459/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6418.4204 - loss: -7.4849 - val_log_likelihood_function: 7480.1704 - val_loss: -8.2402
# Epoch 460/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6658.4868 - loss: -7.4161 - val_log_likelihood_function: 7460.4502 - val_loss: -8.2452
# Epoch 461/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6480.5317 - loss: -7.5340 - val_log_likelihood_function: 7480.3643 - val_loss: -8.2392
# Epoch 462/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - log_likelihood_function: 6632.1128 - loss: -7.4150 - val_log_likelihood_function: 7475.1631 - val_loss: -8.2630
# Epoch 463/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6467.9463 - loss: -7.5306 - val_log_likelihood_function: 7485.0269 - val_loss: -8.2473
# Epoch 464/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6641.4165 - loss: -7.4022 - val_log_likelihood_function: 7472.6689 - val_loss: -8.2577
# Epoch 465/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 6465.1865 - loss: -7.4371 - val_log_likelihood_function: 7493.7012 - val_loss: -8.2714
# Epoch 466/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6643.5664 - loss: -7.3528 - val_log_likelihood_function: 7464.7939 - val_loss: -8.2528
# Epoch 467/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - log_likelihood_function: 6438.1685 - loss: -7.4451 - val_log_likelihood_function: 7488.1885 - val_loss: -8.2593
# Epoch 468/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6652.2983 - loss: -7.4566 - val_log_likelihood_function: 7478.1758 - val_loss: -8.2621
# Epoch 469/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6442.0439 - loss: -7.4419 - val_log_likelihood_function: 7489.6943 - val_loss: -8.2605
# Epoch 470/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6638.9380 - loss: -7.3883 - val_log_likelihood_function: 7463.2144 - val_loss: -8.2548
# Epoch 471/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 6441.3911 - loss: -7.4873 - val_log_likelihood_function: 7477.3232 - val_loss: -8.2422
# Epoch 472/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6659.1694 - loss: -7.3990 - val_log_likelihood_function: 7445.3481 - val_loss: -8.2221
# Epoch 473/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - log_likelihood_function: 6417.9692 - loss: -7.4603 - val_log_likelihood_function: 7476.6426 - val_loss: -8.2480
# Epoch 474/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6619.3193 - loss: -7.4816 - val_log_likelihood_function: 7470.7803 - val_loss: -8.2606
# Epoch 475/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6466.9385 - loss: -7.4943 - val_log_likelihood_function: 7485.9248 - val_loss: -8.2640
# Epoch 476/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6660.1250 - loss: -7.4773 - val_log_likelihood_function: 7475.0483 - val_loss: -8.2702
# Epoch 477/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6384.6875 - loss: -7.4829 - val_log_likelihood_function: 7483.4087 - val_loss: -8.2572
# Epoch 478/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6620.8477 - loss: -7.4435 - val_log_likelihood_function: 7454.7593 - val_loss: -8.2491
# Epoch 479/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - log_likelihood_function: 6459.6758 - loss: -7.5772 - val_log_likelihood_function: 7495.9673 - val_loss: -8.2648
# Epoch 480/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - log_likelihood_function: 6629.7222 - loss: -7.3111 - val_log_likelihood_function: 7455.1157 - val_loss: -8.2327
# Epoch 481/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6409.6348 - loss: -7.4652 - val_log_likelihood_function: 7488.3853 - val_loss: -8.2569
# Epoch 482/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6667.5029 - loss: -7.4512 - val_log_likelihood_function: 7479.5518 - val_loss: -8.2606
# Epoch 483/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6430.4800 - loss: -7.4611 - val_log_likelihood_function: 7470.3599 - val_loss: -8.2430
# Epoch 484/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6653.7915 - loss: -7.3775 - val_log_likelihood_function: 7463.9360 - val_loss: -8.2457
# Epoch 485/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6461.2861 - loss: -7.5320 - val_log_likelihood_function: 7493.4512 - val_loss: -8.2646
# Epoch 486/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6640.1606 - loss: -7.4669 - val_log_likelihood_function: 7487.9907 - val_loss: -8.2801
# Epoch 487/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6479.2090 - loss: -7.5228 - val_log_likelihood_function: 7489.3579 - val_loss: -8.2482
# Epoch 488/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6637.4502 - loss: -7.3921 - val_log_likelihood_function: 7462.5693 - val_loss: -8.2436
# Epoch 489/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6448.7222 - loss: -7.5253 - val_log_likelihood_function: 7484.0859 - val_loss: -8.2504
# Epoch 490/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6654.3462 - loss: -7.5357 - val_log_likelihood_function: 7489.8726 - val_loss: -8.2827
# Epoch 491/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6466.3921 - loss: -7.5285 - val_log_likelihood_function: 7491.7983 - val_loss: -8.2617
# Epoch 492/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6601.4409 - loss: -7.4414 - val_log_likelihood_function: 7454.7153 - val_loss: -8.2479
# Epoch 493/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6418.7876 - loss: -7.5214 - val_log_likelihood_function: 7491.0415 - val_loss: -8.2599
# Epoch 494/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6643.7769 - loss: -7.4085 - val_log_likelihood_function: 7476.0649 - val_loss: -8.2676
# Epoch 495/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - log_likelihood_function: 6475.1387 - loss: -7.5099 - val_log_likelihood_function: 7484.7769 - val_loss: -8.2469
# Epoch 496/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6641.0151 - loss: -7.2584 - val_log_likelihood_function: 7437.2974 - val_loss: -8.2243
# Epoch 497/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6458.9868 - loss: -7.5467 - val_log_likelihood_function: 7486.2578 - val_loss: -8.2586
# Epoch 498/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6668.4517 - loss: -7.4770 - val_log_likelihood_function: 7488.8843 - val_loss: -8.2838
# Epoch 499/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - log_likelihood_function: 6479.1079 - loss: -7.5256 - val_log_likelihood_function: 7495.8379 - val_loss: -8.2702
# Epoch 500/500
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - log_likelihood_function: 6687.2900 - loss: -7.4288 - val_log_likelihood_function: 7457.2339 - val_loss: -8.2556
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - log_likelihood_function: 6803.4785 - loss: -7.7292
# Test loss (Log-Likelihood): -7.90686559677124
# Test log-likelihood: 6879.96484375

# %%
# prompt: đưa ra giá trị loss nhỏ nhất, ở epoch nào

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'history' is the training history object from model.fit
min_loss = np.min(history.history['val_loss'])
min_loss_epoch = np.argmin(history.history['loss'])

print(f"Minimum val loss: {min_loss} at epoch {min_loss_epoch}")
# Out:
# Minimum val loss: -8.283788681030273 at epoch 478

# %%
# prompt: vẽ biểu đồ loss

import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# prompt: đưa ra giá trị dự đoán của mô hình cho test_gen

# Assuming 'model' and 'test_gen' are defined as in the previous code.
# Get predictions for the test data
predictions = model.predict(x_test)

# Print the predictions
predictions
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.03919554],
#        [0.02070002],
#        [0.0221989 ],
#        ...,
#        [0.01041808],
#        [0.01118177],
#        [0.00983271]], dtype=float32)

# %%
predictions.shape
# Out:
# (1185, 1)

# %%
r_t = tf.cast(y_test, dtype=tf.float32)  # Ép kiểu y_true về tf.float32
sigma_t = tf.cast(predictions, dtype=tf.float32) # Cast y_pred to tf.float32 as well
# Constants
import math
pi=math.pi

# Calculate log-likelihood
# Use tf.math.log, tf.math.square, and tf.math.reduce_sum
log_L = np.sum(-0.5 * np.log(2 *pi) - np.log(sigma_t) - (r_t**2) / (2 * sigma_t**2))
log_L
# Out:
# 4091436.8

# %%
# prompt: vẽ biểu đồ chỉ có predictions

import matplotlib.pyplot as plt

# Assuming 'predictions' is already defined from your model.predict call
# and has the correct shape (number of test samples, 1)

plt.figure(figsize=(10, 6))
plt.plot(predictions, label='Predictions')
plt.title('Bitcoin Price Predictions')
plt.ylabel('Predicted Return')
plt.xlabel('Time Step')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming 'predictions' is a NumPy array containing your model's predictions
# Create a Pandas DataFrame from the predictions
predictions_df = pd.DataFrame(predictions, columns=['Predicted Volatility'])

# Specify the output file path in your Google Drive
output_file_path = '/content/drive/MyDrive/predictionsdnnloss.xlsx'

# Export the DataFrame to an Excel file
predictions_df.to_excel(output_file_path, index=False)

print(f"Predictions exported to: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Predictions exported to: /content/drive/MyDrive/predictionsdnnloss.xlsx
